# %% [markdown]
# # Assessing VTE in cancer patients using deep learning synthetic data generation and domain adaptation techniques.

# %% [markdown]
# This notebook contains all the code to reproduce the third experiment of the thesis.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
from sdv.tabular import CopulaGAN, CTGAN,TVAE
from sklearn.metrics import roc_auc_score, confusion_matrix, precision_score, ConfusionMatrixDisplay
# Out:
# C:\Users\SergiBech\anaconda3\envs\sdv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(

# %%
def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions > p)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title('Confusion matrix @{:.2f}'.format(p))
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

# %%
df_alleles = pd.read_csv('oncoth1_with_n_risk_alleles.csv')

# %%
df = pd.read_csv('development_db_score_oncothromb.csv')

# %%
df_alleles['VTE'] = df['VTE'].values

# %% [markdown]
# # Apply paper preprocess pipeline

# %% [markdown]
# The paper selects the following variables:
# - rs4524
# - rs6025
# - rs2232698
# - rs2227631
# - rs268
# - rs169713
# - rs11696364
# - rs5110
# - rs6003

# %%
gen_predictors = ['rs4524', 'rs6025', 'rs2232698', 'rs2227631', 'rs268', 'rs169713', 'rs11696364', 'rs5110','rs6003']

# %%
#Select the risk alleles of the selected features
alleles_ = []
for element in gen_predictors:
    alleles_.append(element + '_n_risk_alleles')
alleles_.append('VTE')
alleles_.append('id')
df_alleles = df_alleles[alleles_].dropna()

# %% [markdown]
# ### Compute Genetic Risk Score

# %%
from sklearn.linear_model import LogisticRegression

y = df_alleles['VTE']
X = df_alleles.drop(columns=['VTE', 'id'])

model = LogisticRegression(fit_intercept = True)
model.fit(X, y)

GRS = (model.coef_ * X).sum(axis=1) + model.intercept_
df_alleles['GRS'] = GRS

# %% [markdown]
# ## Clinical Variables

# %% [markdown]
# - very high risk -> stomach, pancreas
# - high risk -> lung, lymphoma, gynelocoligal, blader, testicular
# - low risk -> colorectal
# - platelet count >= 350x10^9/L -> high risk
# - leukocyte count >= 11x10^9/L -> high risk

# %%
import re
def map_column(row, clinical_dict):
    row = str(row)
    for key, value in clinical_dict.items():
        if re.match(value[0], row):
            return key
    return 'No Clasificado'

# %%
def preprocess_clinical_features(df):
    df_clin = df.iloc[:, 1:21]
    cols_names_clin = df_clin.columns[1:]

    df_clin.loc[df_clin['primary_tumor_simplified'] == 'Colorectal', 'primary_tumor_simplified'] = 0
    df_clin.loc[df_clin['primary_tumor_simplified'] == 'NSCLC', 'primary_tumor_simplified'] = 1
    df_clin.loc[df_clin['primary_tumor_simplified'] == 'Oesophago-gastric', 'primary_tumor_simplified'] = 2
    df_clin.loc[df_clin['primary_tumor_simplified'] == 'Pancreatic', 'primary_tumor_simplified'] = 2

    df_clin.loc[df_clin['leukocytes'] < 11000, 'leukocytes'] = 0
    df_clin.loc[df_clin['leukocytes'] >= 11000, 'leukocytes'] = 1
    df_clin.loc[df_clin['platelets'] < 350000, 'platelets'] = 0
    df_clin.loc[df_clin['platelets'] >= 350000, 'platelets'] = 1

    bmi_risk = {
        1: [r"(Obese: BMI > 30 kg/m2)|( Overweight: BMI ~25-29.9 Kg/m2)"],
        0: [r"(Normal: BMI ~ 18.5-24.9 Kg/m2)|(Underweight: BMI < 18.5 Kg/m2)"],
    }

    tnm_stage_detailed_risk = {
        1: [r"(IA)|(IB)"],
        2: [r"(IIB)|(IIA)|(IIC)"],
        3: [r"(III)|(IIIB)|(IIIA)|(IIIC)"],
        4: [r"(IVB)|(IVA)|(IV)"],
    }


    df_clin['bmi_category'] = df_clin['bmi_category'].apply(lambda x: map_column(x, bmi_risk))
    df_clin['tnm_stage_detailed'] = df_clin['tnm_stage_detailed'].apply(lambda x: map_column(x, tnm_stage_detailed_risk))

    return df_clin

# %%
df_clin = preprocess_clinical_features(df)

# %% [markdown]
# ### Get the clinical variables following the paper (without p-value selection )

# %%
# Drop the variables that are not mentioned in the paper
df_clin = df_clin.drop(['pregnancy', 'oral_contraceptives', 'hemoglobin'], axis=1)
df_clin['id'] = df['id'].values

# %% [markdown]
# Select the predictors of the paper

# %%
clin_predictors = ['tnm_stage_detailed', 'bmi_category', 'primary_tumor_simplified', 'id', 'VTE']
df_clin = df_clin[clin_predictors]

pred = ['id', 'GRS', 'VTE']
predictors = df_alleles[pred]

df_ft = predictors.merge(df_clin, on=['id','VTE'])

df = df_ft.drop(['id'],axis=1)

df['primary_tumor_simplified'] = df['primary_tumor_simplified'].astype(int)

# %%
df.head()
# Out:
#         GRS  VTE  tnm_stage_detailed  bmi_category  primary_tumor_simplified
# 0 -0.309952    1                   4             1                         2
# 1 -1.015882    0                   2             0                         2
# 2 -0.994715    0                   3             1                         2
# 3 -2.016533    0                   2             0                         2
# 4 -1.283673    0                   1             0                         2

# %%
X_real_dupes = df.drop('VTE', axis=1)
y_real_dupes = df['VTE']

# %%
df_no_dupes = df.drop_duplicates()

# %%
X_real_no_dupes = df_no_dupes.drop('VTE', axis=1)
y_real_no_dupes = df_no_dupes['VTE']

# %% [markdown]
# # Generate Data

# %% [raw]
# from sdv.tabular import CopulaGAN
#
# model = CopulaGAN(epochs=2000,
#                   batch_size = 60,
#                   log_frequency=True,
#                 generator_dim=(256, 256),
#                 discriminator_dim=(256, 256), discriminator_steps=5, generator_lr =1e-3,
#                  verbose=True)
#
# model.fit(df_no_dupes)

# %%
model = CopulaGAN.load('best_CopulaGAN.pkl')
# Out:
# C:\Users\SergiBech\anaconda3\envs\sdv\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator BayesianGaussianMixture from version 1.1.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\SergiBech\anaconda3\envs\sdv\lib\site-packages\sdv\utils.py:113: UserWarning: The libraries used to create the model have older versions than your current setup. This may cause errors when sampling.
# rdt used version `1.3.0`; current version is `1.5.0`
# ctgan used version `0.7.1`; current version is `0.7.3`
#   warnings.warn(f'{warning_str}{mismatched_details}')

# %%
synth_gen = model.sample(num_rows=150000)

# %%
from sdv.evaluation import evaluate
print(evaluate(synth_gen, df))
# Out:
# 0.9677915715604801

# %%
import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(synth_gen.drop('VTE', axis=1), synth_gen['VTE'], test_size=0.2, random_state=42)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

clf = LogisticRegression()
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8430666666666666

# %%
y_pred = clf.predict(X_test)
auc_obs = roc_auc_score(y_test, y_pred)
print(auc_obs)
# Out:
# 0.6564436703843195

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test.values, np.round(y_pred))
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=clf.classes_)
disp.plot()
plt.show()

# %%
#Load data form baselines curves
roc_curve_onco = pd.read_csv('no_dups_roc_curve_oncothromb_score_replicated.csv')
pr_curve_onco = pd.read_csv('no_dups_pr_curve_oncothromb_score_replicated.csv')
roc_curve_orig = pd.read_csv('mean_roc_curve_from_cv_oncothromb.csv')
prc_curve_orig = pd.read_csv('pr_curve_oncothromb_score_replicated.csv')

# %%
from sklearn.metrics import roc_curve, auc

# Calculate the false positive rate, true positive rate, and threshold values for the ROC curve
fpr, tpr, thresholds = roc_curve(y_test,clf.predict_proba(X_test)[:,1])
fpr_3, tpr_3, thresholds_3 = roc_curve(y_real_dupes,clf.predict_proba(X_real_dupes)[:,1])
fpr_4, tpr_4, thresholds_4 = roc_curve(y_real_no_dupes,clf.predict_proba(X_real_no_dupes)[:,1])


# Calculate the AUC value
auc_value = auc(fpr, tpr)
auc_value_2 = auc(fpr_3, tpr_3)
auc_value_5 = auc(fpr_4, tpr_4)
auc_value_3 = auc(roc_curve_onco['fpr_points'], roc_curve_onco['mean_tpr'])
auc_value_4 = auc(roc_curve_orig['fpr_points'], roc_curve_orig['mean_tpr'])


# Plot the ROC curve and add the AUC value to the plot
plt.plot(fpr, tpr, label='ROC curve of test synthethic data (AUC = %0.2f)' % auc_value)
plt.plot(fpr_3, tpr_3, color='red',label='ROC curve of real data with duplicates (AUC = %0.2f)' % auc_value_2)
plt.plot(fpr_4, tpr_4,label='ROC curve of real data no duplicates (AUC = %0.2f)' % auc_value_5)
plt.plot(roc_curve_onco['fpr_points'], roc_curve_onco['mean_tpr'], label='Oncothromb no duplictaes (AUC = %0.2f)' % auc_value_3)
plt.plot(roc_curve_orig['fpr_points'], roc_curve_orig['mean_tpr'],color='black', label='Oncothromb with duplicates (AUC = %0.2f)' % auc_value_4)

plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Logistic Regression trained on synthethic data')
plt.legend(loc='lower right', fontsize='small')
# Save figure with higher DPI
#plt.savefig('ROC_curve.png', dpi=300)
plt.show()
# Out:
# C:\Users\SergiBech\anaconda3\envs\sdv\lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# C:\Users\SergiBech\anaconda3\envs\sdv\lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Get precision, recall, and threshold values for test data
precision2, recall2, threshold2 = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])

# Get precision, recall, and threshold values for real data
precision3, recall3, threshold3 = precision_recall_curve(y_real_dupes, clf.predict_proba(X_real_dupes)[:, 1])
precision4, recall4, threshold4 = precision_recall_curve(y_real_no_dupes, clf.predict_proba(X_real_no_dupes)[:, 1])


# Create a new figure and axis object
fig, ax = plt.subplots()

ap = auc(pr_curve_onco.recall_points, pr_curve_onco.mean_precision)
ap_2 = auc(recall2, precision2)
ap_3 = auc(recall3, precision3)
ap_5 = auc(recall4, precision4)
ap_4 = auc(prc_curve_orig.recall, prc_curve_orig.precision)


# Plot the test data Precision-Recall curve
ax.plot(recall2, precision2, label='PRC curve of test synthethic data (AP = %0.2f)' % ap_2)

# Plot the real data Precision-Recall curve
ax.plot(recall3, precision3, color='red', label='PRC curve of real data with duplicates (AP = %0.2f)' % ap_3)
ax.plot(recall4, precision4,  label='PRC curve of real data no duplicates (AP = %0.2f)' % ap_5)


# Plot the synthethic data Precision-Recall curve
ax.plot(pr_curve_onco.recall_points, pr_curve_onco.mean_precision, label='Oncothromb no duplicates (AP = %0.2f)' % ap)
ax.plot(prc_curve_orig.recall, prc_curve_orig.precision,color='black', label='Oncothromb with duplicates (AP = %0.2f)' % ap_4)

# Set the x and y axis labels, title, and legend
ax.set_xlabel("Recall")
ax.set_ylabel("Precision")
ax.set_title("Comparison of 2-class Precision-Recall curves")
plt.legend(loc='best', fontsize='small')

# Save the figure and show it
#plt.savefig('PRC_curve.png', dpi=300)
plt.show()
# Out:
# C:\Users\SergiBech\anaconda3\envs\sdv\lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# C:\Users\SergiBech\anaconda3\envs\sdv\lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# # Train a Deep Learning Model with Synthethic Data

# %%
import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(synth_gen.drop('VTE', axis=1), synth_gen['VTE'], test_size=0.2, random_state=42)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

def make_model(metrics=METRICS):

    # Define the MLP model with skip connections and dropout
    inputs = keras.layers.Input(shape=(X_train.shape[1],))
    
    x = keras.layers.Dense(units=128, activation='relu')(inputs)
    x = keras.layers.Dropout(0.2)(x)
    
    x = keras.layers.Dense(units=64, activation='relu')(x)
    x = keras.layers.Dropout(0.1)(x)
    
   
    x = keras.layers.Dense(units=16, activation='relu')(x)
    
    outputs = keras.layers.Dense(1, activation = 'sigmoid')(x)
    
    
    model = keras.Model(inputs=inputs, outputs=outputs)

    # Compile the model with the specified optimizer, loss function, and metrics
    model.compile(
      optimizer=keras.optimizers.Adam(learning_rate=1e-3),
      loss= keras.losses.BinaryCrossentropy(from_logits=False),
    metrics=metrics)

    return model

# %%
EPOCHS = 100
BATCH_SIZE = 32

early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=8,
    mode='max',
    restore_best_weights=True)

# %%
del model

# %%
from tensorflow.keras.optimizers.schedules import InverseTimeDecay

model = make_model(metrics=METRICS)
baseline_history = model.fit(
    X_train,
    y_train,
    batch_size=BATCH_SIZE,
    callbacks=[early_stopping],
    epochs=EPOCHS,
    validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 3750/3750 [==============================] - 22s 5ms/step - loss: 0.3671 - tp: 8470.0000 - fp: 4852.0000 - tn: 92190.0000 - fn: 14488.0000 - accuracy: 0.8388 - precision: 0.6358 - recall: 0.3689 - auc: 0.8338 - prc: 0.5547 - val_loss: 0.3540 - val_tp: 2250.0000 - val_fp: 1272.0000 - val_tn: 23057.0000 - val_fn: 3421.0000 - val_accuracy: 0.8436 - val_precision: 0.6388 - val_recall: 0.3968 - val_auc: 0.8478 - val_prc: 0.5725
# Epoch 2/100
# 3750/3750 [==============================] - 18s 5ms/step - loss: 0.3621 - tp: 8550.0000 - fp: 4656.0000 - tn: 92386.0000 - fn: 14408.0000 - accuracy: 0.8411 - precision: 0.6474 - recall: 0.3724 - auc: 0.8393 - prc: 0.5648 - val_loss: 0.3535 - val_tp: 2492.0000 - val_fp: 1543.0000 - val_tn: 22786.0000 - val_fn: 3179.0000 - val_accuracy: 0.8426 - val_precision: 0.6176 - val_recall: 0.4394 - val_auc: 0.8490 - val_prc: 0.5734
# Epoch 3/100
# 3750/3750 [==============================] - 18s 5ms/step - loss: 0.3612 - tp: 8643.0000 - fp: 4789.0000 - tn: 92253.0000 - fn: 14315.0000 - accuracy: 0.8408 - precision: 0.6435 - recall: 0.3765 - auc: 0.8403 - prc: 0.5658 - val_loss: 0.3551 - val_tp: 2424.0000 - val_fp: 1450.0000 - val_tn: 22879.0000 - val_fn: 3247.0000 - val_accuracy: 0.8434 - val_precision: 0.6257 - val_recall: 0.4274 - val_auc: 0.8497 - val_prc: 0.5744
# Epoch 4/100
# 3750/3750 [==============================] - 18s 5ms/step - loss: 0.3608 - tp: 8603.0000 - fp: 4753.0000 - tn: 92289.0000 - fn: 14355.0000 - accuracy: 0.8408 - precision: 0.6441 - recall: 0.3747 - auc: 0.8409 - prc: 0.5656 - val_loss: 0.3523 - val_tp: 2427.0000 - val_fp: 1475.0000 - val_tn: 22854.0000 - val_fn: 3244.0000 - val_accuracy: 0.8427 - val_precision: 0.6220 - val_recall: 0.4280 - val_auc: 0.8501 - val_prc: 0.5749
# Epoch 5/100
# 3750/3750 [==============================] - 20s 5ms/step - loss: 0.3603 - tp: 8744.0000 - fp: 4809.0000 - tn: 92233.0000 - fn: 14214.0000 - accuracy: 0.8415 - precision: 0.6452 - recall: 0.3809 - auc: 0.8413 - prc: 0.5685 - val_loss: 0.3510 - val_tp: 2155.0000 - val_fp: 1150.0000 - val_tn: 23179.0000 - val_fn: 3516.0000 - val_accuracy: 0.8445 - val_precision: 0.6520 - val_recall: 0.3800 - val_auc: 0.8504 - val_prc: 0.5744
# Epoch 6/100
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.3602 - tp: 8836.0000 - fp: 4916.0000 - tn: 92126.0000 - fn: 14122.0000 - accuracy: 0.8414 - precision: 0.6425 - recall: 0.3849 - auc: 0.8414 - prc: 0.5668 - val_loss: 0.3535 - val_tp: 1797.0000 - val_fp: 824.0000 - val_tn: 23505.0000 - val_fn: 3874.0000 - val_accuracy: 0.8434 - val_precision: 0.6856 - val_recall: 0.3169 - val_auc: 0.8484 - val_prc: 0.5722
# Epoch 7/100
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.3599 - tp: 8740.0000 - fp: 4804.0000 - tn: 92238.0000 - fn: 14218.0000 - accuracy: 0.8415 - precision: 0.6453 - recall: 0.3807 - auc: 0.8417 - prc: 0.5693 - val_loss: 0.3512 - val_tp: 2109.0000 - val_fp: 1090.0000 - val_tn: 23239.0000 - val_fn: 3562.0000 - val_accuracy: 0.8449 - val_precision: 0.6593 - val_recall: 0.3719 - val_auc: 0.8502 - val_prc: 0.5745
# Epoch 8/100
# 3750/3750 [==============================] - 22s 6ms/step - loss: 0.3598 - tp: 8661.0000 - fp: 4712.0000 - tn: 92330.0000 - fn: 14297.0000 - accuracy: 0.8416 - precision: 0.6476 - recall: 0.3773 - auc: 0.8419 - prc: 0.5691 - val_loss: 0.3534 - val_tp: 2322.0000 - val_fp: 1348.0000 - val_tn: 22981.0000 - val_fn: 3349.0000 - val_accuracy: 0.8434 - val_precision: 0.6327 - val_recall: 0.4095 - val_auc: 0.8501 - val_prc: 0.5743
# Epoch 9/100
# 3750/3750 [==============================] - 29s 8ms/step - loss: 0.3595 - tp: 8747.0000 - fp: 4845.0000 - tn: 92197.0000 - fn: 14211.0000 - accuracy: 0.8412 - precision: 0.6435 - recall: 0.3810 - auc: 0.8422 - prc: 0.5683 - val_loss: 0.3505 - val_tp: 2182.0000 - val_fp: 1176.0000 - val_tn: 23153.0000 - val_fn: 3489.0000 - val_accuracy: 0.8445 - val_precision: 0.6498 - val_recall: 0.3848 - val_auc: 0.8503 - val_prc: 0.5745
# Epoch 10/100
# 3750/3750 [==============================] - 21s 6ms/step - loss: 0.3597 - tp: 8781.0000 - fp: 4812.0000 - tn: 92230.0000 - fn: 14177.0000 - accuracy: 0.8418 - precision: 0.6460 - recall: 0.3825 - auc: 0.8419 - prc: 0.5692 - val_loss: 0.3528 - val_tp: 2192.0000 - val_fp: 1188.0000 - val_tn: 23141.0000 - val_fn: 3479.0000 - val_accuracy: 0.8444 - val_precision: 0.6485 - val_recall: 0.3865 - val_auc: 0.8506 - val_prc: 0.5750
# Epoch 11/100
# 3750/3750 [==============================] - 28s 7ms/step - loss: 0.3596 - tp: 8699.0000 - fp: 4787.0000 - tn: 92255.0000 - fn: 14259.0000 - accuracy: 0.8413 - precision: 0.6450 - recall: 0.3789 - auc: 0.8420 - prc: 0.5689 - val_loss: 0.3506 - val_tp: 2271.0000 - val_fp: 1282.0000 - val_tn: 23047.0000 - val_fn: 3400.0000 - val_accuracy: 0.8439 - val_precision: 0.6392 - val_recall: 0.4005 - val_auc: 0.8507 - val_prc: 0.5749
# Epoch 12/100
# 3750/3750 [==============================] - 22s 6ms/step - loss: 0.3597 - tp: 8665.0000 - fp: 4759.0000 - tn: 92283.0000 - fn: 14293.0000 - accuracy: 0.8412 - precision: 0.6455 - recall: 0.3774 - auc: 0.8421 - prc: 0.5681 - val_loss: 0.3504 - val_tp: 2263.0000 - val_fp: 1276.0000 - val_tn: 23053.0000 - val_fn: 3408.0000 - val_accuracy: 0.8439 - val_precision: 0.6394 - val_recall: 0.3990 - val_auc: 0.8503 - val_prc: 0.5757
# Epoch 13/100
# 3750/3750 [==============================] - 27s 7ms/step - loss: 0.3594 - tp: 8675.0000 - fp: 4764.0000 - tn: 92278.0000 - fn: 14283.0000 - accuracy: 0.8413 - precision: 0.6455 - recall: 0.3779 - auc: 0.8423 - prc: 0.5692 - val_loss: 0.3502 - val_tp: 2302.0000 - val_fp: 1319.0000 - val_tn: 23010.0000 - val_fn: 3369.0000 - val_accuracy: 0.8437 - val_precision: 0.6357 - val_recall: 0.4059 - val_auc: 0.8507 - val_prc: 0.5755
# Epoch 14/100
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.3592 - tp: 8772.0000 - fp: 4835.0000 - tn: 92207.0000 - fn: 14186.0000 - accuracy: 0.8415 - precision: 0.6447 - recall: 0.3821 - auc: 0.8425 - prc: 0.5700 - val_loss: 0.3519 - val_tp: 2264.0000 - val_fp: 1286.0000 - val_tn: 23043.0000 - val_fn: 3407.0000 - val_accuracy: 0.8436 - val_precision: 0.6377 - val_recall: 0.3992 - val_auc: 0.8500 - val_prc: 0.5753
# Epoch 15/100
# 3750/3750 [==============================] - 20s 5ms/step - loss: 0.3596 - tp: 8670.0000 - fp: 4704.0000 - tn: 92338.0000 - fn: 14288.0000 - accuracy: 0.8417 - precision: 0.6483 - recall: 0.3776 - auc: 0.8421 - prc: 0.5692 - val_loss: 0.3519 - val_tp: 2176.0000 - val_fp: 1167.0000 - val_tn: 23162.0000 - val_fn: 3495.0000 - val_accuracy: 0.8446 - val_precision: 0.6509 - val_recall: 0.3837 - val_auc: 0.8498 - val_prc: 0.5749
# Epoch 16/100
# 3750/3750 [==============================] - 30s 8ms/step - loss: 0.3595 - tp: 8672.0000 - fp: 4728.0000 - tn: 92314.0000 - fn: 14286.0000 - accuracy: 0.8415 - precision: 0.6472 - recall: 0.3777 - auc: 0.8421 - prc: 0.5683 - val_loss: 0.3514 - val_tp: 2272.0000 - val_fp: 1287.0000 - val_tn: 23042.0000 - val_fn: 3399.0000 - val_accuracy: 0.8438 - val_precision: 0.6384 - val_recall: 0.4006 - val_auc: 0.8505 - val_prc: 0.5752
# Epoch 17/100
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.3593 - tp: 8617.0000 - fp: 4640.0000 - tn: 92402.0000 - fn: 14341.0000 - accuracy: 0.8418 - precision: 0.6500 - recall: 0.3753 - auc: 0.8425 - prc: 0.5690 - val_loss: 0.3505 - val_tp: 2046.0000 - val_fp: 1021.0000 - val_tn: 23308.0000 - val_fn: 3625.0000 - val_accuracy: 0.8451 - val_precision: 0.6671 - val_recall: 0.3608 - val_auc: 0.8507 - val_prc: 0.5758
# Epoch 18/100
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.3594 - tp: 8699.0000 - fp: 4752.0000 - tn: 92290.0000 - fn: 14259.0000 - accuracy: 0.8416 - precision: 0.6467 - recall: 0.3789 - auc: 0.8424 - prc: 0.5691 - val_loss: 0.3517 - val_tp: 1936.0000 - val_fp: 914.0000 - val_tn: 23415.0000 - val_fn: 3735.0000 - val_accuracy: 0.8450 - val_precision: 0.6793 - val_recall: 0.3414 - val_auc: 0.8508 - val_prc: 0.5754
# Epoch 19/100
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.3593 - tp: 8750.0000 - fp: 4831.0000 - tn: 92211.0000 - fn: 14208.0000 - accuracy: 0.8413 - precision: 0.6443 - recall: 0.3811 - auc: 0.8424 - prc: 0.5696 - val_loss: 0.3518 - val_tp: 2166.0000 - val_fp: 1153.0000 - val_tn: 23176.0000 - val_fn: 3505.0000 - val_accuracy: 0.8447 - val_precision: 0.6526 - val_recall: 0.3819 - val_auc: 0.8508 - val_prc: 0.5779
# Epoch 20/100
# 3750/3750 [==============================] - 20s 5ms/step - loss: 0.3591 - tp: 8683.0000 - fp: 4693.0000 - tn: 92349.0000 - fn: 14275.0000 - accuracy: 0.8419 - precision: 0.6491 - recall: 0.3782 - auc: 0.8426 - prc: 0.5702 - val_loss: 0.3502 - val_tp: 2297.0000 - val_fp: 1319.0000 - val_tn: 23010.0000 - val_fn: 3374.0000 - val_accuracy: 0.8436 - val_precision: 0.6352 - val_recall: 0.4050 - val_auc: 0.8507 - val_prc: 0.5765
# Epoch 21/100
# 3750/3750 [==============================] - 20s 5ms/step - loss: 0.3593 - tp: 8823.0000 - fp: 4906.0000 - tn: 92136.0000 - fn: 14135.0000 - accuracy: 0.8413 - precision: 0.6427 - recall: 0.3843 - auc: 0.8425 - prc: 0.5693 - val_loss: 0.3509 - val_tp: 2165.0000 - val_fp: 1168.0000 - val_tn: 23161.0000 - val_fn: 3506.0000 - val_accuracy: 0.8442 - val_precision: 0.6496 - val_recall: 0.3818 - val_auc: 0.8503 - val_prc: 0.5763
# Epoch 22/100
# 3750/3750 [==============================] - 22s 6ms/step - loss: 0.3590 - tp: 8753.0000 - fp: 4788.0000 - tn: 92254.0000 - fn: 14205.0000 - accuracy: 0.8417 - precision: 0.6464 - recall: 0.3813 - auc: 0.8427 - prc: 0.5711 - val_loss: 0.3511 - val_tp: 2189.0000 - val_fp: 1167.0000 - val_tn: 23162.0000 - val_fn: 3482.0000 - val_accuracy: 0.8450 - val_precision: 0.6523 - val_recall: 0.3860 - val_auc: 0.8504 - val_prc: 0.5752
# Epoch 23/100
# 3750/3750 [==============================] - 21s 6ms/step - loss: 0.3590 - tp: 8588.0000 - fp: 4643.0000 - tn: 92399.0000 - fn: 14370.0000 - accuracy: 0.8416 - precision: 0.6491 - recall: 0.3741 - auc: 0.8427 - prc: 0.5703 - val_loss: 0.3516 - val_tp: 2119.0000 - val_fp: 1121.0000 - val_tn: 23208.0000 - val_fn: 3552.0000 - val_accuracy: 0.8442 - val_precision: 0.6540 - val_recall: 0.3737 - val_auc: 0.8489 - val_prc: 0.5747
# Epoch 24/100
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.3591 - tp: 8703.0000 - fp: 4770.0000 - tn: 92272.0000 - fn: 14255.0000 - accuracy: 0.8415 - precision: 0.6460 - recall: 0.3791 - auc: 0.8426 - prc: 0.5699 - val_loss: 0.3523 - val_tp: 2119.0000 - val_fp: 1108.0000 - val_tn: 23221.0000 - val_fn: 3552.0000 - val_accuracy: 0.8447 - val_precision: 0.6566 - val_recall: 0.3737 - val_auc: 0.8503 - val_prc: 0.5754
# Epoch 25/100
# 3750/3750 [==============================] - 26s 7ms/step - loss: 0.3590 - tp: 8775.0000 - fp: 4802.0000 - tn: 92240.0000 - fn: 14183.0000 - accuracy: 0.8418 - precision: 0.6463 - recall: 0.3822 - auc: 0.8428 - prc: 0.5706 - val_loss: 0.3510 - val_tp: 1947.0000 - val_fp: 935.0000 - val_tn: 23394.0000 - val_fn: 3724.0000 - val_accuracy: 0.8447 - val_precision: 0.6756 - val_recall: 0.3433 - val_auc: 0.8503 - val_prc: 0.5770
# Epoch 26/100
# 3750/3750 [==============================] - 18s 5ms/step - loss: 0.3591 - tp: 8717.0000 - fp: 4762.0000 - tn: 92280.0000 - fn: 14241.0000 - accuracy: 0.8416 - precision: 0.6467 - recall: 0.3797 - auc: 0.8426 - prc: 0.5696 - val_loss: 0.3513 - val_tp: 2072.0000 - val_fp: 1048.0000 - val_tn: 23281.0000 - val_fn: 3599.0000 - val_accuracy: 0.8451 - val_precision: 0.6641 - val_recall: 0.3654 - val_auc: 0.8504 - val_prc: 0.5745
# Epoch 27/100
# 3744/3750 [============================>.] - ETA: 0s - loss: 0.3593 - tp: 8716.0000 - fp: 4790.0000 - tn: 92091.0000 - fn: 14211.0000 - accuracy: 0.8414 - precision: 0.6453 - recall: 0.3802 - auc: 0.8425 - prc: 0.5694Restoring model weights from the end of the best epoch: 19.
# 3750/3750 [==============================] - 22s 6ms/step - loss: 0.3592 - tp: 8732.0000 - fp: 4800.0000 - tn: 92242.0000 - fn: 14226.0000 - accuracy: 0.8414 - precision: 0.6453 - recall: 0.3803 - auc: 0.8425 - prc: 0.5695 - val_loss: 0.3504 - val_tp: 2174.0000 - val_fp: 1162.0000 - val_tn: 23167.0000 - val_fn: 3497.0000 - val_accuracy: 0.8447 - val_precision: 0.6517 - val_recall: 0.3834 - val_auc: 0.8508 - val_prc: 0.5764
# Epoch 27: early stopping

# %%
# Calculate the false positive rate, true positive rate, and threshold values for the ROC curve
fpr, tpr, thresholds = roc_curve(y_test,model.predict(X_test))
fpr_3, tpr_3, thresholds_3 = roc_curve(y_real_dupes,model.predict(X_real_dupes))
fpr_4, tpr_4, thresholds_4 = roc_curve(y_real_no_dupes,model.predict(X_real_no_dupes))


# Calculate the AUC value
auc_value = auc(fpr, tpr)
auc_value_2 = auc(fpr_3, tpr_3)
auc_value_5 = auc(fpr_4, tpr_4)
auc_value_3 = auc(roc_curve_onco['fpr_points'], roc_curve_onco['mean_tpr'])
auc_value_4 = auc(roc_curve_orig['fpr_points'], roc_curve_orig['mean_tpr'])


# Plot the ROC curve and add the AUC value to the plot
plt.plot(fpr, tpr, label='ROC curve of test synthethic data (AUC = %0.2f)' % auc_value)
plt.plot(fpr_3, tpr_3,color='red', label='ROC curve of real data with duplicates (AUC = %0.2f)' % auc_value_2)
plt.plot(fpr_4, tpr_4, label='ROC curve of real data no duplicates (AUC = %0.2f)' % auc_value_5)

plt.plot(roc_curve_onco['fpr_points'], roc_curve_onco['mean_tpr'], label='Oncothromb with duplicates (AUC = %0.2f)' % auc_value_3)
plt.plot(roc_curve_orig['fpr_points'], roc_curve_orig['mean_tpr'], color='black',label='Oncothromb no duplicates (AUC = %0.2f)' % auc_value_4)

plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('MLP trained on synthethic data')
plt.legend(loc='best', fontsize='small')

# Save figure with higher DPI
#plt.savefig('ROC_curve_MLP.png', dpi=300)
plt.show()
# Out:
# 938/938 [==============================] - 3s 3ms/step
# 12/12 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Get precision, recall, and threshold values for test data
precision2, recall2, threshold2 = precision_recall_curve(y_test, model.predict(X_test))

# Get precision, recall, and threshold values for real data
precision3, recall3, threshold3 = precision_recall_curve(y_real_dupes, model.predict(X_real_dupes))
precision4, recall4, threshold4 = precision_recall_curve(y_real_no_dupes, model.predict(X_real_no_dupes))


# Create a new figure and axis object
fig, ax = plt.subplots()

ap = auc(pr_curve_onco.recall_points, pr_curve_onco.mean_precision)
ap_4 = auc(prc_curve_orig.recall, prc_curve_orig.precision)
ap_2 = auc(recall2, precision2)
ap_3 = auc(recall3, precision3)
ap_5 = auc(recall4, precision4)

# Plot the test data Precision-Recall curve
ax.plot(recall2, precision2, label='PRC curve of test synthethic data (AP = %0.2f)' % ap_2)

# Plot the real data Precision-Recall curve
ax.plot(recall3, precision3, color='red', label='PRC curve of real data with duplicates (AP = %0.2f)' % ap_3)
ax.plot(recall4, precision4, label='PRC curve of real data no duplicates (AP = %0.2f)' % ap_5)


# Plot the synthethic data Precision-Recall curve
ax.plot(pr_curve_onco.recall_points, pr_curve_onco.mean_precision, label='Oncothromb with dupes (AP = %0.2f)' % ap)

ax.plot(prc_curve_orig.recall, prc_curve_orig.precision,color='black', label='Oncothromb with no dupes (AP = %0.2f)' % ap_4)


# Set the x and y axis labels, title, and legend
ax.set_xlabel("Recall")
ax.set_ylabel("Precision")
ax.set_title("Comparison of 2-class Precision-Recall curves")
plt.legend(loc='best', fontsize='small')

# Save the figure and show it
#plt.savefig('PRC_curve_MLP.png', dpi=300)
plt.show()
# Out:
# 938/938 [==============================] - 3s 4ms/step
# 12/12 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step

# %% [markdown]
# # Fine-Tune the Model

# %%
neg, pos = np.bincount(df['VTE'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 361
#     Positive: 67 (18.56% of total)

# %%
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
weight_for_0 = (1 / neg) * (total / 2.0)
weight_for_1 = (1 / pos) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 0.61
# Weight for class 1: 2.69

# %%
pretrained_model = keras.models.clone_model(model)

# %% [markdown]
# # 5 fold cv

# %%
class_weight = {0: 0.43, 1:2.69}

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve, auc, average_precision_score

# %%
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=5,
    mode='max',
    restore_best_weights=True)

# %%
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True)

# %%
#load results
#recalls_2 = np.load('recalls_dupes.npy', allow_pickle=True)
#precisions_2 = np.load('precisions_dupes.npy', allow_pickle=True)
#aps_2 = np.load('aps_dupes.npy', allow_pickle=True)
#fprs_2 = np.load('fprs_dupes.npy', allow_pickle=True)
#tprs_2 = np.load('tprs_dupes.npy', allow_pickle=True)
#aucs_2 = np.load('aucs_dupes.npy', allow_pickle=True)

# %%
#Duplicates
X_train_dupes = df.drop(['VTE'], axis=1).reset_index(drop=True)
y_train_dupes = df['VTE'].reset_index(drop=True)

# %%
#No duplicates
X_train_no_dupes = df_no_dupes.drop(['VTE'], axis=1).reset_index(drop=True)
y_train_no_dupes = df_no_dupes['VTE'].reset_index(drop=True)

# %% [markdown]
# Train with duplicates

# %%
fprs = []
tprs = []
aucs = []
precisions = []
recalls = []
aps = []

# %%
for i, (train_index, test_index) in enumerate(skf.split(X_train_dupes, y_train_dupes)):
    
    # Get the training and validation data for this fold
    X_train_fold = X_train_dupes.iloc[train_index]
    y_train_fold = y_train_dupes[train_index]
    X_val_fold = X_train_dupes.iloc[test_index]
    y_val_fold = y_train_dupes.iloc[test_index]
    
    pretrained_model = keras.models.clone_model(model)
    
    # Get the output of the second-to-last layer in the model
    second_to_last_layer = pretrained_model.layers[-2].output
    # Get the output layer of the pretrained model
    output_layer = pretrained_model.layers[-1].activation
    ## Add a new Dense layer with 8 units and 'relu' activation
   # new_layer = keras.layers.Dense(8, activation='relu')(second_to_last_layer)
   # new_layer = keras.layers.Dense(16, activation='relu')(new_layer)

    # Create a new model that includes both the new layer and the output layer of the pretrained model
    #new_output = keras.layers.Dense(1, activation=output_layer)(new_layer)
    outputs = keras.layers.Dense(1, activation = 'sigmoid')(second_to_last_layer)
    # Create a new model that includes the new layer
    new_model = keras.models.Model(inputs=pretrained_model.input, outputs=outputs)

    # Freeze the weights of all layers except the new layer
    #for layer in new_model.layers[:-2]:
     #   layer.trainable = True
    # Compile the model with the specified optimizer, loss function, and metrics
    new_model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3), # Use a smaller learning rate for fine-tuning
        loss=keras.losses.BinaryCrossentropy(from_logits=False),
        metrics=METRICS)
    
        # Train the model on your real data
    pre_trained_history = new_model.fit(
        X_train_fold, y_train_fold,
        batch_size=16,
        epochs=25,
        class_weight= class_weight,
        callbacks = [early_stopping],
        validation_data=(X_val_fold, y_val_fold))

    # Save the fine-tuned model
    #pretrained_model.save('fine_tuned_model.h5'
    
    fpr, tpr, thresholds = roc_curve(y_val_fold,new_model.predict(X_val_fold))
    fprs.append(fpr)
    tprs.append(tpr)
    precision, recall, thresholds = precision_recall_curve(y_val_fold, new_model.predict(X_val_fold))
    precisions.append(precision)
    recalls.append(recall)
    # Compute the AUC for this fold
    auc_val = roc_auc_score(y_val_fold, new_model.predict(X_val_fold))
    aucs.append(auc_val)
    # Compute the AP for this fold
    ap = average_precision_score(y_val_fold, new_model.predict(X_val_fold))   
    aps.append(ap)
    if i != 4:
        del new_model
# Out:
# Epoch 1/25
# 18/18 [==============================] - 4s 86ms/step - loss: 0.5710 - tp: 58.0000 - fp: 220.0000 - tn: 61.0000 - fn: 7.0000 - accuracy: 0.3439 - precision: 0.2086 - recall: 0.8923 - auc: 0.6209 - prc: 0.3178 - val_loss: 0.7510 - val_tp: 14.0000 - val_fp: 56.0000 - val_tn: 3.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.2329 - val_precision: 0.2000 - val_recall: 1.0000 - val_auc: 0.8172 - val_prc: 0.5132
# Epoch 2/25
# 18/18 [==============================] - 0s 13ms/step - loss: 0.5469 - tp: 53.0000 - fp: 229.0000 - tn: 6.0000 - fn: 0.0000e+00 - accuracy: 0.2049 - precision: 0.1879 - recall: 1.0000 - auc: 0.6921 - prc: 0.3242 - val_loss: 0.7938 - val_tp: 14.0000 - val_fp: 54.0000 - val_tn: 5.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.2603 - val_precision: 0.2059 - val_recall: 1.0000 - val_auc: 0.8238 - val_prc: 0.4791
# Epoch 3/25
# 18/18 [==============================] - 0s 13ms/step - loss: 0.5339 - tp: 50.0000 - fp: 198.0000 - tn: 37.0000 - fn: 3.0000 - accuracy: 0.3021 - precision: 0.2016 - recall: 0.9434 - auc: 0.7091 - prc: 0.3973 - val_loss: 0.6879 - val_tp: 13.0000 - val_fp: 30.0000 - val_tn: 29.0000 - val_fn: 1.0000 - val_accuracy: 0.5753 - val_precision: 0.3023 - val_recall: 0.9286 - val_auc: 0.8414 - val_prc: 0.5437
# Epoch 4/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.5340 - tp: 50.0000 - fp: 180.0000 - tn: 55.0000 - fn: 3.0000 - accuracy: 0.3646 - precision: 0.2174 - recall: 0.9434 - auc: 0.6999 - prc: 0.3188 - val_loss: 0.7214 - val_tp: 13.0000 - val_fp: 39.0000 - val_tn: 20.0000 - val_fn: 1.0000 - val_accuracy: 0.4521 - val_precision: 0.2500 - val_recall: 0.9286 - val_auc: 0.8384 - val_prc: 0.5468
# Epoch 5/25
# 18/18 [==============================] - 0s 13ms/step - loss: 0.5168 - tp: 48.0000 - fp: 132.0000 - tn: 103.0000 - fn: 5.0000 - accuracy: 0.5243 - precision: 0.2667 - recall: 0.9057 - auc: 0.7253 - prc: 0.3732 - val_loss: 0.7342 - val_tp: 13.0000 - val_fp: 39.0000 - val_tn: 20.0000 - val_fn: 1.0000 - val_accuracy: 0.4521 - val_precision: 0.2500 - val_recall: 0.9286 - val_auc: 0.8420 - val_prc: 0.5529
# Epoch 6/25
# 18/18 [==============================] - 0s 18ms/step - loss: 0.5090 - tp: 47.0000 - fp: 154.0000 - tn: 81.0000 - fn: 6.0000 - accuracy: 0.4444 - precision: 0.2338 - recall: 0.8868 - auc: 0.7385 - prc: 0.4159 - val_loss: 0.6539 - val_tp: 12.0000 - val_fp: 25.0000 - val_tn: 34.0000 - val_fn: 2.0000 - val_accuracy: 0.6301 - val_precision: 0.3243 - val_recall: 0.8571 - val_auc: 0.8408 - val_prc: 0.5621
# Epoch 7/25
# 18/18 [==============================] - 0s 15ms/step - loss: 0.5073 - tp: 42.0000 - fp: 97.0000 - tn: 138.0000 - fn: 11.0000 - accuracy: 0.6250 - precision: 0.3022 - recall: 0.7925 - auc: 0.7344 - prc: 0.3703 - val_loss: 0.6833 - val_tp: 12.0000 - val_fp: 28.0000 - val_tn: 31.0000 - val_fn: 2.0000 - val_accuracy: 0.5890 - val_precision: 0.3000 - val_recall: 0.8571 - val_auc: 0.8341 - val_prc: 0.5642
# Epoch 8/25
# 18/18 [==============================] - 0s 14ms/step - loss: 0.5002 - tp: 44.0000 - fp: 110.0000 - tn: 125.0000 - fn: 9.0000 - accuracy: 0.5868 - precision: 0.2857 - recall: 0.8302 - auc: 0.7352 - prc: 0.4203 - val_loss: 0.5717 - val_tp: 12.0000 - val_fp: 17.0000 - val_tn: 42.0000 - val_fn: 2.0000 - val_accuracy: 0.7397 - val_precision: 0.4138 - val_recall: 0.8571 - val_auc: 0.8208 - val_prc: 0.5270
# Epoch 9/25
# 18/18 [==============================] - 0s 13ms/step - loss: 0.4938 - tp: 45.0000 - fp: 104.0000 - tn: 131.0000 - fn: 8.0000 - accuracy: 0.6111 - precision: 0.3020 - recall: 0.8491 - auc: 0.7400 - prc: 0.4191 - val_loss: 0.7314 - val_tp: 12.0000 - val_fp: 34.0000 - val_tn: 25.0000 - val_fn: 2.0000 - val_accuracy: 0.5068 - val_precision: 0.2609 - val_recall: 0.8571 - val_auc: 0.8257 - val_prc: 0.5548
# Epoch 10/25
# 18/18 [==============================] - 0s 16ms/step - loss: 0.5033 - tp: 44.0000 - fp: 126.0000 - tn: 109.0000 - fn: 9.0000 - accuracy: 0.5312 - precision: 0.2588 - recall: 0.8302 - auc: 0.7308 - prc: 0.3800 - val_loss: 0.7545 - val_tp: 12.0000 - val_fp: 35.0000 - val_tn: 24.0000 - val_fn: 2.0000 - val_accuracy: 0.4932 - val_precision: 0.2553 - val_recall: 0.8571 - val_auc: 0.8208 - val_prc: 0.5170
# Epoch 11/25
# 18/18 [==============================] - 0s 14ms/step - loss: 0.4890 - tp: 47.0000 - fp: 130.0000 - tn: 105.0000 - fn: 6.0000 - accuracy: 0.5278 - precision: 0.2655 - recall: 0.8868 - auc: 0.7616 - prc: 0.3685 - val_loss: 0.6722 - val_tp: 12.0000 - val_fp: 29.0000 - val_tn: 30.0000 - val_fn: 2.0000 - val_accuracy: 0.5753 - val_precision: 0.2927 - val_recall: 0.8571 - val_auc: 0.8160 - val_prc: 0.5421
# Epoch 12/25
# 12/18 [===================>..........] - ETA: 0s - loss: 0.4422 - tp: 20.0000 - fp: 54.0000 - tn: 109.0000 - fn: 9.0000 - accuracy: 0.6719 - precision: 0.2703 - recall: 0.6897 - auc: 0.7655 - prc: 0.4366 Restoring model weights from the end of the best epoch: 7.
# 18/18 [==============================] - 0s 14ms/step - loss: 0.4986 - tp: 37.0000 - fp: 81.0000 - tn: 154.0000 - fn: 16.0000 - accuracy: 0.6632 - precision: 0.3136 - recall: 0.6981 - auc: 0.7460 - prc: 0.4082 - val_loss: 0.7583 - val_tp: 12.0000 - val_fp: 35.0000 - val_tn: 24.0000 - val_fn: 2.0000 - val_accuracy: 0.4932 - val_precision: 0.2553 - val_recall: 0.8571 - val_auc: 0.8214 - val_prc: 0.5542
# Epoch 12: early stopping
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# Epoch 1/25
# 19/19 [==============================] - 4s 84ms/step - loss: 0.5661 - tp: 59.0000 - fp: 220.0000 - tn: 75.0000 - fn: 8.0000 - accuracy: 0.3702 - precision: 0.2115 - recall: 0.8806 - auc: 0.6344 - prc: 0.3284 - val_loss: 0.7555 - val_tp: 14.0000 - val_fp: 56.0000 - val_tn: 2.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.2222 - val_precision: 0.2000 - val_recall: 1.0000 - val_auc: 0.6589 - val_prc: 0.2964
# Epoch 2/25
# 19/19 [==============================] - 0s 12ms/step - loss: 0.5403 - tp: 47.0000 - fp: 174.0000 - tn: 62.0000 - fn: 6.0000 - accuracy: 0.3772 - precision: 0.2127 - recall: 0.8868 - auc: 0.6953 - prc: 0.3714 - val_loss: 0.7354 - val_tp: 10.0000 - val_fp: 32.0000 - val_tn: 26.0000 - val_fn: 4.0000 - val_accuracy: 0.5000 - val_precision: 0.2381 - val_recall: 0.7143 - val_auc: 0.6459 - val_prc: 0.2467
# Epoch 3/25
# 19/19 [==============================] - 0s 12ms/step - loss: 0.5194 - tp: 45.0000 - fp: 131.0000 - tn: 105.0000 - fn: 8.0000 - accuracy: 0.5190 - precision: 0.2557 - recall: 0.8491 - auc: 0.7203 - prc: 0.4440 - val_loss: 0.7396 - val_tp: 11.0000 - val_fp: 30.0000 - val_tn: 28.0000 - val_fn: 3.0000 - val_accuracy: 0.5417 - val_precision: 0.2683 - val_recall: 0.7857 - val_auc: 0.6724 - val_prc: 0.2619
# Epoch 4/25
# 19/19 [==============================] - 0s 12ms/step - loss: 0.5127 - tp: 45.0000 - fp: 138.0000 - tn: 98.0000 - fn: 8.0000 - accuracy: 0.4948 - precision: 0.2459 - recall: 0.8491 - auc: 0.7260 - prc: 0.3833 - val_loss: 0.7201 - val_tp: 9.0000 - val_fp: 28.0000 - val_tn: 30.0000 - val_fn: 5.0000 - val_accuracy: 0.5417 - val_precision: 0.2432 - val_recall: 0.6429 - val_auc: 0.6767 - val_prc: 0.2674
# Epoch 5/25
# 19/19 [==============================] - 0s 12ms/step - loss: 0.5074 - tp: 38.0000 - fp: 83.0000 - tn: 153.0000 - fn: 15.0000 - accuracy: 0.6609 - precision: 0.3140 - recall: 0.7170 - auc: 0.7354 - prc: 0.4206 - val_loss: 0.6897 - val_tp: 8.0000 - val_fp: 27.0000 - val_tn: 31.0000 - val_fn: 6.0000 - val_accuracy: 0.5417 - val_precision: 0.2286 - val_recall: 0.5714 - val_auc: 0.6767 - val_prc: 0.2734
# Epoch 6/25
# 12/19 [=================>............] - ETA: 0s - loss: 0.4758 - tp: 31.0000 - fp: 71.0000 - tn: 85.0000 - fn: 5.0000 - accuracy: 0.6042 - precision: 0.3039 - recall: 0.8611 - auc: 0.7810 - prc: 0.5238Restoring model weights from the end of the best epoch: 1.
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4668 - tp: 47.0000 - fp: 113.0000 - tn: 123.0000 - fn: 6.0000 - accuracy: 0.5882 - precision: 0.2937 - recall: 0.8868 - auc: 0.7941 - prc: 0.4650 - val_loss: 0.7341 - val_tp: 11.0000 - val_fp: 29.0000 - val_tn: 29.0000 - val_fn: 3.0000 - val_accuracy: 0.5556 - val_precision: 0.2750 - val_recall: 0.7857 - val_auc: 0.6804 - val_prc: 0.2758
# Epoch 6: early stopping
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# Epoch 1/25
# 19/19 [==============================] - 7s 134ms/step - loss: 0.5760 - tp: 55.0000 - fp: 188.0000 - tn: 105.0000 - fn: 13.0000 - accuracy: 0.4432 - precision: 0.2263 - recall: 0.8088 - auc: 0.5982 - prc: 0.2492 - val_loss: 0.8696 - val_tp: 13.0000 - val_fp: 59.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.1806 - val_precision: 0.1806 - val_recall: 1.0000 - val_auc: 0.6871 - val_prc: 0.3323
# Epoch 2/25
# 19/19 [==============================] - 0s 11ms/step - loss: 0.5541 - tp: 51.0000 - fp: 199.0000 - tn: 36.0000 - fn: 3.0000 - accuracy: 0.3010 - precision: 0.2040 - recall: 0.9444 - auc: 0.6610 - prc: 0.2720 - val_loss: 0.7806 - val_tp: 12.0000 - val_fp: 51.0000 - val_tn: 8.0000 - val_fn: 1.0000 - val_accuracy: 0.2778 - val_precision: 0.1905 - val_recall: 0.9231 - val_auc: 0.7229 - val_prc: 0.5624
# Epoch 3/25
# 19/19 [==============================] - 0s 11ms/step - loss: 0.5323 - tp: 43.0000 - fp: 135.0000 - tn: 100.0000 - fn: 11.0000 - accuracy: 0.4948 - precision: 0.2416 - recall: 0.7963 - auc: 0.7268 - prc: 0.4054 - val_loss: 0.7917 - val_tp: 12.0000 - val_fp: 45.0000 - val_tn: 14.0000 - val_fn: 1.0000 - val_accuracy: 0.3611 - val_precision: 0.2105 - val_recall: 0.9231 - val_auc: 0.7288 - val_prc: 0.5539
# Epoch 4/25
# 19/19 [==============================] - 0s 22ms/step - loss: 0.5144 - tp: 50.0000 - fp: 148.0000 - tn: 87.0000 - fn: 4.0000 - accuracy: 0.4740 - precision: 0.2525 - recall: 0.9259 - auc: 0.7240 - prc: 0.3804 - val_loss: 0.7301 - val_tp: 12.0000 - val_fp: 38.0000 - val_tn: 21.0000 - val_fn: 1.0000 - val_accuracy: 0.4583 - val_precision: 0.2400 - val_recall: 0.9231 - val_auc: 0.7432 - val_prc: 0.5778
# Epoch 5/25
# 19/19 [==============================] - 0s 19ms/step - loss: 0.5020 - tp: 43.0000 - fp: 100.0000 - tn: 135.0000 - fn: 11.0000 - accuracy: 0.6159 - precision: 0.3007 - recall: 0.7963 - auc: 0.7438 - prc: 0.3780 - val_loss: 0.8913 - val_tp: 12.0000 - val_fp: 44.0000 - val_tn: 15.0000 - val_fn: 1.0000 - val_accuracy: 0.3750 - val_precision: 0.2143 - val_recall: 0.9231 - val_auc: 0.7471 - val_prc: 0.5461
# Epoch 6/25
# 19/19 [==============================] - 0s 25ms/step - loss: 0.5059 - tp: 44.0000 - fp: 132.0000 - tn: 103.0000 - fn: 10.0000 - accuracy: 0.5087 - precision: 0.2500 - recall: 0.8148 - auc: 0.7353 - prc: 0.4047 - val_loss: 0.6792 - val_tp: 11.0000 - val_fp: 28.0000 - val_tn: 31.0000 - val_fn: 2.0000 - val_accuracy: 0.5833 - val_precision: 0.2821 - val_recall: 0.8462 - val_auc: 0.7503 - val_prc: 0.5737
# Epoch 7/25
# 19/19 [==============================] - 0s 22ms/step - loss: 0.5021 - tp: 42.0000 - fp: 92.0000 - tn: 143.0000 - fn: 12.0000 - accuracy: 0.6401 - precision: 0.3134 - recall: 0.7778 - auc: 0.7468 - prc: 0.3795 - val_loss: 0.8188 - val_tp: 12.0000 - val_fp: 41.0000 - val_tn: 18.0000 - val_fn: 1.0000 - val_accuracy: 0.4167 - val_precision: 0.2264 - val_recall: 0.9231 - val_auc: 0.7477 - val_prc: 0.5719
# Epoch 8/25
# 19/19 [==============================] - 0s 24ms/step - loss: 0.4898 - tp: 48.0000 - fp: 132.0000 - tn: 103.0000 - fn: 6.0000 - accuracy: 0.5225 - precision: 0.2667 - recall: 0.8889 - auc: 0.7540 - prc: 0.4478 - val_loss: 0.7490 - val_tp: 11.0000 - val_fp: 34.0000 - val_tn: 25.0000 - val_fn: 2.0000 - val_accuracy: 0.5000 - val_precision: 0.2444 - val_recall: 0.8462 - val_auc: 0.7405 - val_prc: 0.5762
# Epoch 9/25
# 19/19 [==============================] - 0s 12ms/step - loss: 0.4981 - tp: 41.0000 - fp: 109.0000 - tn: 126.0000 - fn: 13.0000 - accuracy: 0.5779 - precision: 0.2733 - recall: 0.7593 - auc: 0.7402 - prc: 0.3885 - val_loss: 0.7907 - val_tp: 12.0000 - val_fp: 38.0000 - val_tn: 21.0000 - val_fn: 1.0000 - val_accuracy: 0.4583 - val_precision: 0.2400 - val_recall: 0.9231 - val_auc: 0.7497 - val_prc: 0.5804
# Epoch 10/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4679 - tp: 50.0000 - fp: 119.0000 - tn: 116.0000 - fn: 4.0000 - accuracy: 0.5744 - precision: 0.2959 - recall: 0.9259 - auc: 0.7825 - prc: 0.4075 - val_loss: 0.7060 - val_tp: 11.0000 - val_fp: 30.0000 - val_tn: 29.0000 - val_fn: 2.0000 - val_accuracy: 0.5556 - val_precision: 0.2683 - val_recall: 0.8462 - val_auc: 0.7542 - val_prc: 0.5748
# Epoch 11/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4747 - tp: 47.0000 - fp: 95.0000 - tn: 140.0000 - fn: 7.0000 - accuracy: 0.6471 - precision: 0.3310 - recall: 0.8704 - auc: 0.7657 - prc: 0.4180 - val_loss: 0.8201 - val_tp: 12.0000 - val_fp: 38.0000 - val_tn: 21.0000 - val_fn: 1.0000 - val_accuracy: 0.4583 - val_precision: 0.2400 - val_recall: 0.9231 - val_auc: 0.7484 - val_prc: 0.5456
# Epoch 12/25
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5100 - tp: 47.0000 - fp: 132.0000 - tn: 103.0000 - fn: 7.0000 - accuracy: 0.5190 - precision: 0.2626 - recall: 0.8704 - auc: 0.7429 - prc: 0.3915 - val_loss: 0.7934 - val_tp: 12.0000 - val_fp: 35.0000 - val_tn: 24.0000 - val_fn: 1.0000 - val_accuracy: 0.5000 - val_precision: 0.2553 - val_recall: 0.9231 - val_auc: 0.7503 - val_prc: 0.5854
# Epoch 13/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4907 - tp: 50.0000 - fp: 134.0000 - tn: 101.0000 - fn: 4.0000 - accuracy: 0.5225 - precision: 0.2717 - recall: 0.9259 - auc: 0.7683 - prc: 0.4338 - val_loss: 0.8512 - val_tp: 12.0000 - val_fp: 39.0000 - val_tn: 20.0000 - val_fn: 1.0000 - val_accuracy: 0.4444 - val_precision: 0.2353 - val_recall: 0.9231 - val_auc: 0.7275 - val_prc: 0.5512
# Epoch 14/25
# 19/19 [==============================] - 0s 17ms/step - loss: 0.4832 - tp: 48.0000 - fp: 109.0000 - tn: 126.0000 - fn: 6.0000 - accuracy: 0.6021 - precision: 0.3057 - recall: 0.8889 - auc: 0.7556 - prc: 0.3861 - val_loss: 0.7049 - val_tp: 10.0000 - val_fp: 32.0000 - val_tn: 27.0000 - val_fn: 3.0000 - val_accuracy: 0.5139 - val_precision: 0.2381 - val_recall: 0.7692 - val_auc: 0.7308 - val_prc: 0.5572
# Epoch 15/25
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4838 - tp: 46.0000 - fp: 107.0000 - tn: 128.0000 - fn: 8.0000 - accuracy: 0.6021 - precision: 0.3007 - recall: 0.8519 - auc: 0.7583 - prc: 0.4220 - val_loss: 0.7943 - val_tp: 11.0000 - val_fp: 37.0000 - val_tn: 22.0000 - val_fn: 2.0000 - val_accuracy: 0.4583 - val_precision: 0.2292 - val_recall: 0.8462 - val_auc: 0.7366 - val_prc: 0.5506
# Epoch 16/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4917 - tp: 48.0000 - fp: 122.0000 - tn: 113.0000 - fn: 6.0000 - accuracy: 0.5571 - precision: 0.2824 - recall: 0.8889 - auc: 0.7583 - prc: 0.3898 - val_loss: 0.7559 - val_tp: 11.0000 - val_fp: 30.0000 - val_tn: 29.0000 - val_fn: 2.0000 - val_accuracy: 0.5556 - val_precision: 0.2683 - val_recall: 0.8462 - val_auc: 0.7405 - val_prc: 0.5604
# Epoch 17/25
# 12/19 [=================>............] - ETA: 0s - loss: 0.5040 - tp: 29.0000 - fp: 58.0000 - tn: 96.0000 - fn: 9.0000 - accuracy: 0.6510 - precision: 0.3333 - recall: 0.7632 - auc: 0.7556 - prc: 0.4593 Restoring model weights from the end of the best epoch: 12.
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5103 - tp: 41.0000 - fp: 95.0000 - tn: 140.0000 - fn: 13.0000 - accuracy: 0.6263 - precision: 0.3015 - recall: 0.7593 - auc: 0.7302 - prc: 0.3848 - val_loss: 0.6997 - val_tp: 10.0000 - val_fp: 30.0000 - val_tn: 29.0000 - val_fn: 3.0000 - val_accuracy: 0.5417 - val_precision: 0.2500 - val_recall: 0.7692 - val_auc: 0.7373 - val_prc: 0.5594
# Epoch 17: early stopping
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 3ms/step
# Epoch 1/25
# 19/19 [==============================] - 5s 82ms/step - loss: 0.6072 - tp: 40.0000 - fp: 151.0000 - tn: 143.0000 - fn: 27.0000 - accuracy: 0.5069 - precision: 0.2094 - recall: 0.5970 - auc: 0.5584 - prc: 0.2771 - val_loss: 0.7929 - val_tp: 13.0000 - val_fp: 59.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.1806 - val_precision: 0.1806 - val_recall: 1.0000 - val_auc: 0.5860 - val_prc: 0.2241
# Epoch 2/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5599 - tp: 53.0000 - fp: 207.0000 - tn: 28.0000 - fn: 1.0000 - accuracy: 0.2803 - precision: 0.2038 - recall: 0.9815 - auc: 0.6585 - prc: 0.3187 - val_loss: 0.7875 - val_tp: 13.0000 - val_fp: 56.0000 - val_tn: 3.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.2222 - val_precision: 0.1884 - val_recall: 1.0000 - val_auc: 0.6610 - val_prc: 0.3860
# Epoch 3/25
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5466 - tp: 51.0000 - fp: 182.0000 - tn: 53.0000 - fn: 3.0000 - accuracy: 0.3599 - precision: 0.2189 - recall: 0.9444 - auc: 0.6968 - prc: 0.2896 - val_loss: 0.7386 - val_tp: 10.0000 - val_fp: 39.0000 - val_tn: 20.0000 - val_fn: 3.0000 - val_accuracy: 0.4167 - val_precision: 0.2041 - val_recall: 0.7692 - val_auc: 0.6643 - val_prc: 0.4157
# Epoch 4/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5344 - tp: 43.0000 - fp: 124.0000 - tn: 111.0000 - fn: 11.0000 - accuracy: 0.5329 - precision: 0.2575 - recall: 0.7963 - auc: 0.7053 - prc: 0.3314 - val_loss: 0.6785 - val_tp: 8.0000 - val_fp: 26.0000 - val_tn: 33.0000 - val_fn: 5.0000 - val_accuracy: 0.5694 - val_precision: 0.2353 - val_recall: 0.6154 - val_auc: 0.6832 - val_prc: 0.4404
# Epoch 5/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5056 - tp: 44.0000 - fp: 110.0000 - tn: 125.0000 - fn: 10.0000 - accuracy: 0.5848 - precision: 0.2857 - recall: 0.8148 - auc: 0.7469 - prc: 0.3930 - val_loss: 0.7558 - val_tp: 9.0000 - val_fp: 34.0000 - val_tn: 25.0000 - val_fn: 4.0000 - val_accuracy: 0.4722 - val_precision: 0.2093 - val_recall: 0.6923 - val_auc: 0.6832 - val_prc: 0.4318
# Epoch 6/25
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5098 - tp: 48.0000 - fp: 138.0000 - tn: 97.0000 - fn: 6.0000 - accuracy: 0.5017 - precision: 0.2581 - recall: 0.8889 - auc: 0.7274 - prc: 0.3359 - val_loss: 0.7040 - val_tp: 9.0000 - val_fp: 28.0000 - val_tn: 31.0000 - val_fn: 4.0000 - val_accuracy: 0.5556 - val_precision: 0.2432 - val_recall: 0.6923 - val_auc: 0.7119 - val_prc: 0.4470
# Epoch 7/25
# 19/19 [==============================] - 0s 16ms/step - loss: 0.5058 - tp: 43.0000 - fp: 111.0000 - tn: 124.0000 - fn: 11.0000 - accuracy: 0.5779 - precision: 0.2792 - recall: 0.7963 - auc: 0.7310 - prc: 0.4331 - val_loss: 0.6924 - val_tp: 11.0000 - val_fp: 28.0000 - val_tn: 31.0000 - val_fn: 2.0000 - val_accuracy: 0.5833 - val_precision: 0.2821 - val_recall: 0.8462 - val_auc: 0.7347 - val_prc: 0.4654
# Epoch 8/25
# 19/19 [==============================] - 0s 17ms/step - loss: 0.4782 - tp: 45.0000 - fp: 99.0000 - tn: 136.0000 - fn: 9.0000 - accuracy: 0.6263 - precision: 0.3125 - recall: 0.8333 - auc: 0.7786 - prc: 0.4568 - val_loss: 0.6104 - val_tp: 9.0000 - val_fp: 20.0000 - val_tn: 39.0000 - val_fn: 4.0000 - val_accuracy: 0.6667 - val_precision: 0.3103 - val_recall: 0.6923 - val_auc: 0.7490 - val_prc: 0.4981
# Epoch 9/25
# 19/19 [==============================] - 0s 25ms/step - loss: 0.5103 - tp: 44.0000 - fp: 124.0000 - tn: 111.0000 - fn: 10.0000 - accuracy: 0.5363 - precision: 0.2619 - recall: 0.8148 - auc: 0.7216 - prc: 0.3772 - val_loss: 0.7371 - val_tp: 11.0000 - val_fp: 29.0000 - val_tn: 30.0000 - val_fn: 2.0000 - val_accuracy: 0.5694 - val_precision: 0.2750 - val_recall: 0.8462 - val_auc: 0.7379 - val_prc: 0.4755
# Epoch 10/25
# 19/19 [==============================] - 0s 15ms/step - loss: 0.5034 - tp: 50.0000 - fp: 149.0000 - tn: 86.0000 - fn: 4.0000 - accuracy: 0.4706 - precision: 0.2513 - recall: 0.9259 - auc: 0.7427 - prc: 0.4273 - val_loss: 0.7022 - val_tp: 11.0000 - val_fp: 26.0000 - val_tn: 33.0000 - val_fn: 2.0000 - val_accuracy: 0.6111 - val_precision: 0.2973 - val_recall: 0.8462 - val_auc: 0.7314 - val_prc: 0.4692
# Epoch 11/25
# 19/19 [==============================] - 0s 19ms/step - loss: 0.4962 - tp: 45.0000 - fp: 114.0000 - tn: 121.0000 - fn: 9.0000 - accuracy: 0.5744 - precision: 0.2830 - recall: 0.8333 - auc: 0.7430 - prc: 0.3989 - val_loss: 0.6041 - val_tp: 9.0000 - val_fp: 21.0000 - val_tn: 38.0000 - val_fn: 4.0000 - val_accuracy: 0.6528 - val_precision: 0.3000 - val_recall: 0.6923 - val_auc: 0.7438 - val_prc: 0.4962
# Epoch 12/25
# 19/19 [==============================] - 0s 16ms/step - loss: 0.4850 - tp: 42.0000 - fp: 99.0000 - tn: 136.0000 - fn: 12.0000 - accuracy: 0.6159 - precision: 0.2979 - recall: 0.7778 - auc: 0.7632 - prc: 0.4342 - val_loss: 0.7165 - val_tp: 11.0000 - val_fp: 26.0000 - val_tn: 33.0000 - val_fn: 2.0000 - val_accuracy: 0.6111 - val_precision: 0.2973 - val_recall: 0.8462 - val_auc: 0.7373 - val_prc: 0.4749
# Epoch 13/25
# 13/19 [===================>..........] - ETA: 0s - loss: 0.5118 - tp: 35.0000 - fp: 81.0000 - tn: 84.0000 - fn: 8.0000 - accuracy: 0.5721 - precision: 0.3017 - recall: 0.8140 - auc: 0.7481 - prc: 0.4327 Restoring model weights from the end of the best epoch: 8.
# 19/19 [==============================] - 0s 11ms/step - loss: 0.4895 - tp: 45.0000 - fp: 114.0000 - tn: 121.0000 - fn: 9.0000 - accuracy: 0.5744 - precision: 0.2830 - recall: 0.8333 - auc: 0.7525 - prc: 0.3875 - val_loss: 0.6446 - val_tp: 9.0000 - val_fp: 22.0000 - val_tn: 37.0000 - val_fn: 4.0000 - val_accuracy: 0.6389 - val_precision: 0.2903 - val_recall: 0.6923 - val_auc: 0.7405 - val_prc: 0.4777
# Epoch 13: early stopping
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 6ms/step
# Epoch 1/25
# 19/19 [==============================] - 5s 90ms/step - loss: 0.5857 - tp: 60.0000 - fp: 247.0000 - tn: 47.0000 - fn: 7.0000 - accuracy: 0.2964 - precision: 0.1954 - recall: 0.8955 - auc: 0.5564 - prc: 0.2582 - val_loss: 0.7637 - val_tp: 13.0000 - val_fp: 56.0000 - val_tn: 3.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.2222 - val_precision: 0.1884 - val_recall: 1.0000 - val_auc: 0.8142 - val_prc: 0.4011
# Epoch 2/25
# 19/19 [==============================] - 0s 12ms/step - loss: 0.5541 - tp: 48.0000 - fp: 160.0000 - tn: 75.0000 - fn: 6.0000 - accuracy: 0.4256 - precision: 0.2308 - recall: 0.8889 - auc: 0.6585 - prc: 0.2910 - val_loss: 0.7126 - val_tp: 12.0000 - val_fp: 35.0000 - val_tn: 24.0000 - val_fn: 1.0000 - val_accuracy: 0.5000 - val_precision: 0.2553 - val_recall: 0.9231 - val_auc: 0.7816 - val_prc: 0.3692
# Epoch 3/25
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5550 - tp: 47.0000 - fp: 171.0000 - tn: 64.0000 - fn: 7.0000 - accuracy: 0.3841 - precision: 0.2156 - recall: 0.8704 - auc: 0.6322 - prc: 0.2791 - val_loss: 0.7660 - val_tp: 12.0000 - val_fp: 45.0000 - val_tn: 14.0000 - val_fn: 1.0000 - val_accuracy: 0.3611 - val_precision: 0.2105 - val_recall: 0.9231 - val_auc: 0.7953 - val_prc: 0.3657
# Epoch 4/25
# 19/19 [==============================] - 0s 12ms/step - loss: 0.5392 - tp: 46.0000 - fp: 126.0000 - tn: 109.0000 - fn: 8.0000 - accuracy: 0.5363 - precision: 0.2674 - recall: 0.8519 - auc: 0.6898 - prc: 0.3059 - val_loss: 0.6966 - val_tp: 12.0000 - val_fp: 27.0000 - val_tn: 32.0000 - val_fn: 1.0000 - val_accuracy: 0.6111 - val_precision: 0.3077 - val_recall: 0.9231 - val_auc: 0.7842 - val_prc: 0.3788
# Epoch 5/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5260 - tp: 50.0000 - fp: 163.0000 - tn: 72.0000 - fn: 4.0000 - accuracy: 0.4221 - precision: 0.2347 - recall: 0.9259 - auc: 0.7059 - prc: 0.3556 - val_loss: 0.7349 - val_tp: 12.0000 - val_fp: 28.0000 - val_tn: 31.0000 - val_fn: 1.0000 - val_accuracy: 0.5972 - val_precision: 0.3000 - val_recall: 0.9231 - val_auc: 0.7842 - val_prc: 0.3639
# Epoch 6/25
# 11/19 [================>.............] - ETA: 0s - loss: 0.4719 - tp: 22.0000 - fp: 71.0000 - tn: 76.0000 - fn: 7.0000 - accuracy: 0.5568 - precision: 0.2366 - recall: 0.7586 - auc: 0.7606 - prc: 0.4126Restoring model weights from the end of the best epoch: 1.
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5111 - tp: 39.0000 - fp: 98.0000 - tn: 137.0000 - fn: 15.0000 - accuracy: 0.6090 - precision: 0.2847 - recall: 0.7222 - auc: 0.7227 - prc: 0.4113 - val_loss: 0.6089 - val_tp: 12.0000 - val_fp: 20.0000 - val_tn: 39.0000 - val_fn: 1.0000 - val_accuracy: 0.7083 - val_precision: 0.3750 - val_recall: 0.9231 - val_auc: 0.7875 - val_prc: 0.3933
# Epoch 6: early stopping
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step

# %% [markdown]
# Compute mean AUC and PRC curves

# %%
# Determine the common set of FPR values
fpr_common_dupes = np.unique(np.concatenate(fprs))

# Interpolate the TPR values at the common set of FPR values for each fold
tprs_interp = []
for i in range(n_splits):
    tprs_interp.append(np.interp(fpr_common_dupes, fprs[i], tprs[i]))

# Calculate the mean and standard deviation of the interpolated TPR values and AUCs across all folds
mean_tpr_dupes = np.mean(tprs_interp, axis=0)
std_tpr_dupes = np.std(tprs_interp, axis=0)

# %%
# Determine the common set of recall values
recall_common_dupes = np.unique(np.concatenate(recalls))
# Interpolate the precision values at the common set of recall values for each fold
precisions_interp = []
for i in range(n_splits):
    precisions_interp.append(np.interp(recall_common_dupes, recalls[i][::-1], precisions[i][::-1]))
    
# Calculate the mean and standard deviation of the interpolated precision values and AUCs across all folds
mean_precision_dupes = np.mean(precisions_interp, axis=0)

# %% [markdown]
# Train with no duplicates

# %%
fprs = []
tprs = []
aucs = []
precisions = []
recalls = []
aps_no_dupes = []

# %%
del new_model
for i, (train_index, test_index) in enumerate(skf.split(X_train_no_dupes, y_train_no_dupes)):
    
    # Get the training and validation data for this fold
    X_train_fold = X_train_no_dupes.iloc[train_index]
    y_train_fold = y_train_no_dupes[train_index]
    X_val_fold = X_train_no_dupes.iloc[test_index]
    y_val_fold = y_train_no_dupes.iloc[test_index]
    
    pretrained_model = keras.models.clone_model(model)
    
    # Get the output of the second-to-last layer in the model
    second_to_last_layer = pretrained_model.layers[-2].output
    # Get the output layer of the pretrained model
    output_layer = pretrained_model.layers[-1].activation
    ## Add a new Dense layer with 8 units and 'relu' activation
   # new_layer = keras.layers.Dense(8, activation='relu')(second_to_last_layer)
   # new_layer = keras.layers.Dense(16, activation='relu')(new_layer)

    # Create a new model that includes both the new layer and the output layer of the pretrained model
    #new_output = keras.layers.Dense(1, activation=output_layer)(new_layer)
    outputs = keras.layers.Dense(1, activation = 'sigmoid')(second_to_last_layer)
    # Create a new model that includes the new layer
    new_model = keras.models.Model(inputs=pretrained_model.input, outputs=outputs)

    # Freeze the weights of all layers except the new layer
    #for layer in new_model.layers[:-2]:
     #   layer.trainable = True
    # Compile the model with the specified optimizer, loss function, and metrics
    new_model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3), # Use a smaller learning rate for fine-tuning
        loss=keras.losses.BinaryCrossentropy(from_logits=False),
        metrics=METRICS)
    
        # Train the model on your real data
    pre_trained_history = new_model.fit(
        X_train_fold, y_train_fold,
        batch_size=16,
        epochs=25,
        class_weight= class_weight,
        callbacks = [early_stopping],
        validation_data=(X_val_fold, y_val_fold))

    # Save the fine-tuned model
    #pretrained_model.save('fine_tuned_model.h5'
    
    fpr, tpr, thresholds = roc_curve(y_val_fold,new_model.predict(X_val_fold))
    fprs.append(fpr)
    tprs.append(tpr)
    precision, recall, thresholds = precision_recall_curve(y_val_fold, new_model.predict(X_val_fold))
    precisions.append(precision)
    recalls.append(recall)
    # Compute the AUC for this fold
    auc_val = roc_auc_score(y_val_fold, new_model.predict(X_val_fold))
    aucs.append(auc_val)
    # Compute the AP for this fold
    ap = average_precision_score(y_val_fold, new_model.predict(X_val_fold))   
    aps_no_dupes.append(ap)
    if i != 4:
        del new_model
# Out:
# Epoch 1/25
# 15/15 [==============================] - 4s 101ms/step - loss: 0.6493 - tp: 21.0000 - fp: 71.0000 - tn: 174.0000 - fn: 40.0000 - accuracy: 0.6373 - precision: 0.2283 - recall: 0.3443 - auc: 0.5740 - prc: 0.2683 - val_loss: 0.7286 - val_tp: 13.0000 - val_fp: 42.0000 - val_tn: 4.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.2881 - val_precision: 0.2364 - val_recall: 1.0000 - val_auc: 0.7132 - val_prc: 0.3586
# Epoch 2/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5948 - tp: 44.0000 - fp: 168.0000 - tn: 18.0000 - fn: 4.0000 - accuracy: 0.2650 - precision: 0.2075 - recall: 0.9167 - auc: 0.5987 - prc: 0.2628 - val_loss: 0.7992 - val_tp: 13.0000 - val_fp: 45.0000 - val_tn: 1.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.2373 - val_precision: 0.2241 - val_recall: 1.0000 - val_auc: 0.7425 - val_prc: 0.4331
# Epoch 3/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5651 - tp: 46.0000 - fp: 157.0000 - tn: 29.0000 - fn: 2.0000 - accuracy: 0.3205 - precision: 0.2266 - recall: 0.9583 - auc: 0.7176 - prc: 0.3548 - val_loss: 0.7686 - val_tp: 13.0000 - val_fp: 33.0000 - val_tn: 13.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.4407 - val_precision: 0.2826 - val_recall: 1.0000 - val_auc: 0.7224 - val_prc: 0.3662
# Epoch 4/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5431 - tp: 42.0000 - fp: 117.0000 - tn: 69.0000 - fn: 6.0000 - accuracy: 0.4744 - precision: 0.2642 - recall: 0.8750 - auc: 0.7480 - prc: 0.4804 - val_loss: 0.7860 - val_tp: 13.0000 - val_fp: 32.0000 - val_tn: 14.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.4576 - val_precision: 0.2889 - val_recall: 1.0000 - val_auc: 0.7349 - val_prc: 0.4893
# Epoch 5/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5304 - tp: 43.0000 - fp: 114.0000 - tn: 72.0000 - fn: 5.0000 - accuracy: 0.4915 - precision: 0.2739 - recall: 0.8958 - auc: 0.7292 - prc: 0.4076 - val_loss: 0.7975 - val_tp: 13.0000 - val_fp: 29.0000 - val_tn: 17.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.5085 - val_precision: 0.3095 - val_recall: 1.0000 - val_auc: 0.7299 - val_prc: 0.5194
# Epoch 6/25
# 15/15 [==============================] - 0s 21ms/step - loss: 0.5087 - tp: 41.0000 - fp: 96.0000 - tn: 90.0000 - fn: 7.0000 - accuracy: 0.5598 - precision: 0.2993 - recall: 0.8542 - auc: 0.7594 - prc: 0.4299 - val_loss: 0.7890 - val_tp: 13.0000 - val_fp: 26.0000 - val_tn: 20.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.5593 - val_precision: 0.3333 - val_recall: 1.0000 - val_auc: 0.7283 - val_prc: 0.4805
# Epoch 7/25
# 15/15 [==============================] - 0s 19ms/step - loss: 0.5442 - tp: 42.0000 - fp: 126.0000 - tn: 60.0000 - fn: 6.0000 - accuracy: 0.4359 - precision: 0.2500 - recall: 0.8750 - auc: 0.6893 - prc: 0.3441 - val_loss: 0.8581 - val_tp: 13.0000 - val_fp: 31.0000 - val_tn: 15.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.4746 - val_precision: 0.2955 - val_recall: 1.0000 - val_auc: 0.7425 - val_prc: 0.4981
# Epoch 8/25
# 15/15 [==============================] - 0s 19ms/step - loss: 0.5236 - tp: 40.0000 - fp: 103.0000 - tn: 83.0000 - fn: 8.0000 - accuracy: 0.5256 - precision: 0.2797 - recall: 0.8333 - auc: 0.7429 - prc: 0.4721 - val_loss: 0.7645 - val_tp: 12.0000 - val_fp: 25.0000 - val_tn: 21.0000 - val_fn: 1.0000 - val_accuracy: 0.5593 - val_precision: 0.3243 - val_recall: 0.9231 - val_auc: 0.7341 - val_prc: 0.4852
# Epoch 9/25
# 15/15 [==============================] - 0s 18ms/step - loss: 0.5082 - tp: 43.0000 - fp: 106.0000 - tn: 80.0000 - fn: 5.0000 - accuracy: 0.5256 - precision: 0.2886 - recall: 0.8958 - auc: 0.7559 - prc: 0.4920 - val_loss: 0.8817 - val_tp: 13.0000 - val_fp: 31.0000 - val_tn: 15.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.4746 - val_precision: 0.2955 - val_recall: 1.0000 - val_auc: 0.7433 - val_prc: 0.4923
# Epoch 10/25
# 11/15 [=====================>........] - ETA: 0s - loss: 0.4985 - tp: 31.0000 - fp: 79.0000 - tn: 60.0000 - fn: 6.0000 - accuracy: 0.5170 - precision: 0.2818 - recall: 0.8378 - auc: 0.7680 - prc: 0.5429 Restoring model weights from the end of the best epoch: 5.
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5000 - tp: 40.0000 - fp: 102.0000 - tn: 84.0000 - fn: 8.0000 - accuracy: 0.5299 - precision: 0.2817 - recall: 0.8333 - auc: 0.7539 - prc: 0.4621 - val_loss: 0.7283 - val_tp: 11.0000 - val_fp: 24.0000 - val_tn: 22.0000 - val_fn: 2.0000 - val_accuracy: 0.5593 - val_precision: 0.3143 - val_recall: 0.8462 - val_auc: 0.7333 - val_prc: 0.5077
# Epoch 10: early stopping
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# Epoch 1/25
# 15/15 [==============================] - 4s 101ms/step - loss: 0.5910 - tp: 57.0000 - fp: 198.0000 - tn: 33.0000 - fn: 5.0000 - accuracy: 0.3072 - precision: 0.2235 - recall: 0.9194 - auc: 0.6608 - prc: 0.3346 - val_loss: 0.8300 - val_tp: 12.0000 - val_fp: 47.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.2034 - val_precision: 0.2034 - val_recall: 1.0000 - val_auc: 0.7615 - val_prc: 0.4227
# Epoch 2/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5703 - tp: 49.0000 - fp: 183.0000 - tn: 2.0000 - fn: 0.0000e+00 - accuracy: 0.2179 - precision: 0.2112 - recall: 1.0000 - auc: 0.6915 - prc: 0.4130 - val_loss: 0.8620 - val_tp: 12.0000 - val_fp: 45.0000 - val_tn: 2.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.2373 - val_precision: 0.2105 - val_recall: 1.0000 - val_auc: 0.7775 - val_prc: 0.4402
# Epoch 3/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5664 - tp: 49.0000 - fp: 175.0000 - tn: 10.0000 - fn: 0.0000e+00 - accuracy: 0.2521 - precision: 0.2188 - recall: 1.0000 - auc: 0.6667 - prc: 0.4038 - val_loss: 0.8050 - val_tp: 12.0000 - val_fp: 37.0000 - val_tn: 10.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.3729 - val_precision: 0.2449 - val_recall: 1.0000 - val_auc: 0.7482 - val_prc: 0.3963
# Epoch 4/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5549 - tp: 44.0000 - fp: 118.0000 - tn: 67.0000 - fn: 5.0000 - accuracy: 0.4744 - precision: 0.2716 - recall: 0.8980 - auc: 0.7040 - prc: 0.3884 - val_loss: 0.7304 - val_tp: 11.0000 - val_fp: 31.0000 - val_tn: 16.0000 - val_fn: 1.0000 - val_accuracy: 0.4576 - val_precision: 0.2619 - val_recall: 0.9167 - val_auc: 0.7358 - val_prc: 0.3674
# Epoch 5/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5260 - tp: 45.0000 - fp: 124.0000 - tn: 61.0000 - fn: 4.0000 - accuracy: 0.4530 - precision: 0.2663 - recall: 0.9184 - auc: 0.7515 - prc: 0.4604 - val_loss: 0.8059 - val_tp: 12.0000 - val_fp: 33.0000 - val_tn: 14.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.4407 - val_precision: 0.2667 - val_recall: 1.0000 - val_auc: 0.7287 - val_prc: 0.3694
# Epoch 6/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5269 - tp: 44.0000 - fp: 109.0000 - tn: 76.0000 - fn: 5.0000 - accuracy: 0.5128 - precision: 0.2876 - recall: 0.8980 - auc: 0.7355 - prc: 0.4691 - val_loss: 0.7798 - val_tp: 11.0000 - val_fp: 30.0000 - val_tn: 17.0000 - val_fn: 1.0000 - val_accuracy: 0.4746 - val_precision: 0.2683 - val_recall: 0.9167 - val_auc: 0.7234 - val_prc: 0.3569
# Epoch 7/25
# 11/15 [=====================>........] - ETA: 0s - loss: 0.5001 - tp: 28.0000 - fp: 71.0000 - tn: 71.0000 - fn: 6.0000 - accuracy: 0.5625 - precision: 0.2828 - recall: 0.8235 - auc: 0.7488 - prc: 0.5041                      Restoring model weights from the end of the best epoch: 2.
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5146 - tp: 40.0000 - fp: 89.0000 - tn: 96.0000 - fn: 9.0000 - accuracy: 0.5812 - precision: 0.3101 - recall: 0.8163 - auc: 0.7481 - prc: 0.4629 - val_loss: 0.7981 - val_tp: 11.0000 - val_fp: 30.0000 - val_tn: 17.0000 - val_fn: 1.0000 - val_accuracy: 0.4746 - val_precision: 0.2683 - val_recall: 0.9167 - val_auc: 0.7199 - val_prc: 0.3542
# Epoch 7: early stopping
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch 1/25
# 15/15 [==============================] - 4s 101ms/step - loss: 0.6006 - tp: 59.0000 - fp: 215.0000 - tn: 17.0000 - fn: 2.0000 - accuracy: 0.2594 - precision: 0.2153 - recall: 0.9672 - auc: 0.5773 - prc: 0.2765 - val_loss: 0.9049 - val_tp: 12.0000 - val_fp: 47.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.2034 - val_precision: 0.2034 - val_recall: 1.0000 - val_auc: 0.6277 - val_prc: 0.3124
# Epoch 2/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5876 - tp: 48.0000 - fp: 171.0000 - tn: 14.0000 - fn: 1.0000 - accuracy: 0.2650 - precision: 0.2192 - recall: 0.9796 - auc: 0.5964 - prc: 0.2475 - val_loss: 0.7731 - val_tp: 12.0000 - val_fp: 44.0000 - val_tn: 3.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.2542 - val_precision: 0.2143 - val_recall: 1.0000 - val_auc: 0.7624 - val_prc: 0.4402
# Epoch 3/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5663 - tp: 49.0000 - fp: 177.0000 - tn: 8.0000 - fn: 0.0000e+00 - accuracy: 0.2436 - precision: 0.2168 - recall: 1.0000 - auc: 0.6770 - prc: 0.3420 - val_loss: 0.9106 - val_tp: 12.0000 - val_fp: 46.0000 - val_tn: 1.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.2203 - val_precision: 0.2069 - val_recall: 1.0000 - val_auc: 0.7553 - val_prc: 0.4333
# Epoch 4/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5313 - tp: 49.0000 - fp: 148.0000 - tn: 37.0000 - fn: 0.0000e+00 - accuracy: 0.3675 - precision: 0.2487 - recall: 1.0000 - auc: 0.7632 - prc: 0.4007 - val_loss: 0.7490 - val_tp: 10.0000 - val_fp: 30.0000 - val_tn: 17.0000 - val_fn: 2.0000 - val_accuracy: 0.4576 - val_precision: 0.2500 - val_recall: 0.8333 - val_auc: 0.7828 - val_prc: 0.4790
# Epoch 5/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5264 - tp: 44.0000 - fp: 110.0000 - tn: 75.0000 - fn: 5.0000 - accuracy: 0.5085 - precision: 0.2857 - recall: 0.8980 - auc: 0.7528 - prc: 0.4276 - val_loss: 0.7508 - val_tp: 10.0000 - val_fp: 26.0000 - val_tn: 21.0000 - val_fn: 2.0000 - val_accuracy: 0.5254 - val_precision: 0.2778 - val_recall: 0.8333 - val_auc: 0.7642 - val_prc: 0.4631
# Epoch 6/25
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5235 - tp: 47.0000 - fp: 121.0000 - tn: 64.0000 - fn: 2.0000 - accuracy: 0.4744 - precision: 0.2798 - recall: 0.9592 - auc: 0.7485 - prc: 0.4448 - val_loss: 0.7319 - val_tp: 10.0000 - val_fp: 22.0000 - val_tn: 25.0000 - val_fn: 2.0000 - val_accuracy: 0.5932 - val_precision: 0.3125 - val_recall: 0.8333 - val_auc: 0.7722 - val_prc: 0.4744
# Epoch 7/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5296 - tp: 40.0000 - fp: 87.0000 - tn: 98.0000 - fn: 9.0000 - accuracy: 0.5897 - precision: 0.3150 - recall: 0.8163 - auc: 0.7344 - prc: 0.4157 - val_loss: 0.6739 - val_tp: 10.0000 - val_fp: 17.0000 - val_tn: 30.0000 - val_fn: 2.0000 - val_accuracy: 0.6780 - val_precision: 0.3704 - val_recall: 0.8333 - val_auc: 0.7801 - val_prc: 0.4862
# Epoch 8/25
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5074 - tp: 45.0000 - fp: 115.0000 - tn: 70.0000 - fn: 4.0000 - accuracy: 0.4915 - precision: 0.2812 - recall: 0.9184 - auc: 0.7674 - prc: 0.4565 - val_loss: 0.8200 - val_tp: 10.0000 - val_fp: 28.0000 - val_tn: 19.0000 - val_fn: 2.0000 - val_accuracy: 0.4915 - val_precision: 0.2632 - val_recall: 0.8333 - val_auc: 0.7810 - val_prc: 0.4780
# Epoch 9/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5130 - tp: 44.0000 - fp: 105.0000 - tn: 80.0000 - fn: 5.0000 - accuracy: 0.5299 - precision: 0.2953 - recall: 0.8980 - auc: 0.7532 - prc: 0.4268 - val_loss: 0.6463 - val_tp: 10.0000 - val_fp: 17.0000 - val_tn: 30.0000 - val_fn: 2.0000 - val_accuracy: 0.6780 - val_precision: 0.3704 - val_recall: 0.8333 - val_auc: 0.7828 - val_prc: 0.4836
# Epoch 10/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5172 - tp: 40.0000 - fp: 98.0000 - tn: 87.0000 - fn: 9.0000 - accuracy: 0.5427 - precision: 0.2899 - recall: 0.8163 - auc: 0.7397 - prc: 0.4166 - val_loss: 0.7255 - val_tp: 10.0000 - val_fp: 22.0000 - val_tn: 25.0000 - val_fn: 2.0000 - val_accuracy: 0.5932 - val_precision: 0.3125 - val_recall: 0.8333 - val_auc: 0.7775 - val_prc: 0.4866
# Epoch 11/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5032 - tp: 41.0000 - fp: 93.0000 - tn: 92.0000 - fn: 8.0000 - accuracy: 0.5684 - precision: 0.3060 - recall: 0.8367 - auc: 0.7603 - prc: 0.5033 - val_loss: 0.6838 - val_tp: 10.0000 - val_fp: 18.0000 - val_tn: 29.0000 - val_fn: 2.0000 - val_accuracy: 0.6610 - val_precision: 0.3571 - val_recall: 0.8333 - val_auc: 0.7819 - val_prc: 0.5333
# Epoch 12/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4928 - tp: 45.0000 - fp: 96.0000 - tn: 89.0000 - fn: 4.0000 - accuracy: 0.5726 - precision: 0.3191 - recall: 0.9184 - auc: 0.7729 - prc: 0.4483 - val_loss: 0.6661 - val_tp: 10.0000 - val_fp: 18.0000 - val_tn: 29.0000 - val_fn: 2.0000 - val_accuracy: 0.6610 - val_precision: 0.3571 - val_recall: 0.8333 - val_auc: 0.7855 - val_prc: 0.5344
# Epoch 13/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5180 - tp: 41.0000 - fp: 95.0000 - tn: 90.0000 - fn: 8.0000 - accuracy: 0.5598 - precision: 0.3015 - recall: 0.8367 - auc: 0.7296 - prc: 0.4388 - val_loss: 0.7452 - val_tp: 10.0000 - val_fp: 23.0000 - val_tn: 24.0000 - val_fn: 2.0000 - val_accuracy: 0.5763 - val_precision: 0.3030 - val_recall: 0.8333 - val_auc: 0.7828 - val_prc: 0.5058
# Epoch 14/25
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5134 - tp: 44.0000 - fp: 103.0000 - tn: 82.0000 - fn: 5.0000 - accuracy: 0.5385 - precision: 0.2993 - recall: 0.8980 - auc: 0.7363 - prc: 0.3951 - val_loss: 0.6607 - val_tp: 10.0000 - val_fp: 20.0000 - val_tn: 27.0000 - val_fn: 2.0000 - val_accuracy: 0.6271 - val_precision: 0.3333 - val_recall: 0.8333 - val_auc: 0.7890 - val_prc: 0.5001
# Epoch 15/25
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4953 - tp: 41.0000 - fp: 77.0000 - tn: 108.0000 - fn: 8.0000 - accuracy: 0.6368 - precision: 0.3475 - recall: 0.8367 - auc: 0.7717 - prc: 0.5047 - val_loss: 0.6305 - val_tp: 10.0000 - val_fp: 17.0000 - val_tn: 30.0000 - val_fn: 2.0000 - val_accuracy: 0.6780 - val_precision: 0.3704 - val_recall: 0.8333 - val_auc: 0.7952 - val_prc: 0.5220
# Epoch 16/25
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5156 - tp: 43.0000 - fp: 111.0000 - tn: 74.0000 - fn: 6.0000 - accuracy: 0.5000 - precision: 0.2792 - recall: 0.8776 - auc: 0.7349 - prc: 0.4182 - val_loss: 0.7231 - val_tp: 10.0000 - val_fp: 23.0000 - val_tn: 24.0000 - val_fn: 2.0000 - val_accuracy: 0.5763 - val_precision: 0.3030 - val_recall: 0.8333 - val_auc: 0.7784 - val_prc: 0.4872
# Epoch 17/25
# 11/15 [=====================>........] - ETA: 0s - loss: 0.5205 - tp: 36.0000 - fp: 83.0000 - tn: 52.0000 - fn: 5.0000 - accuracy: 0.5000 - precision: 0.3025 - recall: 0.8780 - auc: 0.7541 - prc: 0.4813 Restoring model weights from the end of the best epoch: 12.
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4979 - tp: 44.0000 - fp: 106.0000 - tn: 79.0000 - fn: 5.0000 - accuracy: 0.5256 - precision: 0.2933 - recall: 0.8980 - auc: 0.7596 - prc: 0.4569 - val_loss: 0.6845 - val_tp: 10.0000 - val_fp: 21.0000 - val_tn: 26.0000 - val_fn: 2.0000 - val_accuracy: 0.6102 - val_precision: 0.3226 - val_recall: 0.8333 - val_auc: 0.7748 - val_prc: 0.4807
# Epoch 17: early stopping
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 6ms/step
# Epoch 1/25
# 15/15 [==============================] - 4s 98ms/step - loss: 0.6243 - tp: 42.0000 - fp: 143.0000 - tn: 90.0000 - fn: 19.0000 - accuracy: 0.4490 - precision: 0.2270 - recall: 0.6885 - auc: 0.5803 - prc: 0.3024 - val_loss: 0.9439 - val_tp: 12.0000 - val_fp: 46.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.2069 - val_precision: 0.2069 - val_recall: 1.0000 - val_auc: 0.6132 - val_prc: 0.2484
# Epoch 2/25
# 15/15 [==============================] - 0s 17ms/step - loss: 0.5739 - tp: 49.0000 - fp: 180.0000 - tn: 6.0000 - fn: 0.0000e+00 - accuracy: 0.2340 - precision: 0.2140 - recall: 1.0000 - auc: 0.6511 - prc: 0.2830 - val_loss: 0.8997 - val_tp: 12.0000 - val_fp: 46.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.2069 - val_precision: 0.2069 - val_recall: 1.0000 - val_auc: 0.6621 - val_prc: 0.3520
# Epoch 3/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5664 - tp: 44.0000 - fp: 137.0000 - tn: 49.0000 - fn: 5.0000 - accuracy: 0.3957 - precision: 0.2431 - recall: 0.8980 - auc: 0.6541 - prc: 0.3289 - val_loss: 0.8111 - val_tp: 10.0000 - val_fp: 32.0000 - val_tn: 14.0000 - val_fn: 2.0000 - val_accuracy: 0.4138 - val_precision: 0.2381 - val_recall: 0.8333 - val_auc: 0.6902 - val_prc: 0.3721
# Epoch 4/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5564 - tp: 46.0000 - fp: 146.0000 - tn: 40.0000 - fn: 3.0000 - accuracy: 0.3660 - precision: 0.2396 - recall: 0.9388 - auc: 0.6810 - prc: 0.3588 - val_loss: 0.8796 - val_tp: 10.0000 - val_fp: 35.0000 - val_tn: 11.0000 - val_fn: 2.0000 - val_accuracy: 0.3621 - val_precision: 0.2222 - val_recall: 0.8333 - val_auc: 0.7192 - val_prc: 0.3913
# Epoch 5/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5462 - tp: 44.0000 - fp: 121.0000 - tn: 65.0000 - fn: 5.0000 - accuracy: 0.4638 - precision: 0.2667 - recall: 0.8980 - auc: 0.6929 - prc: 0.3225 - val_loss: 0.7558 - val_tp: 10.0000 - val_fp: 27.0000 - val_tn: 19.0000 - val_fn: 2.0000 - val_accuracy: 0.5000 - val_precision: 0.2703 - val_recall: 0.8333 - val_auc: 0.7328 - val_prc: 0.4062
# Epoch 6/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5240 - tp: 44.0000 - fp: 101.0000 - tn: 85.0000 - fn: 5.0000 - accuracy: 0.5489 - precision: 0.3034 - recall: 0.8980 - auc: 0.7320 - prc: 0.4263 - val_loss: 0.8263 - val_tp: 10.0000 - val_fp: 30.0000 - val_tn: 16.0000 - val_fn: 2.0000 - val_accuracy: 0.4483 - val_precision: 0.2500 - val_recall: 0.8333 - val_auc: 0.7400 - val_prc: 0.4043
# Epoch 7/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5189 - tp: 43.0000 - fp: 112.0000 - tn: 74.0000 - fn: 6.0000 - accuracy: 0.4979 - precision: 0.2774 - recall: 0.8776 - auc: 0.7392 - prc: 0.5021 - val_loss: 0.7870 - val_tp: 10.0000 - val_fp: 27.0000 - val_tn: 19.0000 - val_fn: 2.0000 - val_accuracy: 0.5000 - val_precision: 0.2703 - val_recall: 0.8333 - val_auc: 0.7591 - val_prc: 0.4287
# Epoch 8/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5020 - tp: 43.0000 - fp: 93.0000 - tn: 93.0000 - fn: 6.0000 - accuracy: 0.5787 - precision: 0.3162 - recall: 0.8776 - auc: 0.7530 - prc: 0.4767 - val_loss: 0.7249 - val_tp: 10.0000 - val_fp: 21.0000 - val_tn: 25.0000 - val_fn: 2.0000 - val_accuracy: 0.6034 - val_precision: 0.3226 - val_recall: 0.8333 - val_auc: 0.7627 - val_prc: 0.4439
# Epoch 9/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5089 - tp: 42.0000 - fp: 103.0000 - tn: 83.0000 - fn: 7.0000 - accuracy: 0.5319 - precision: 0.2897 - recall: 0.8571 - auc: 0.7421 - prc: 0.3895 - val_loss: 0.8655 - val_tp: 10.0000 - val_fp: 29.0000 - val_tn: 17.0000 - val_fn: 2.0000 - val_accuracy: 0.4655 - val_precision: 0.2564 - val_recall: 0.8333 - val_auc: 0.7400 - val_prc: 0.3955
# Epoch 10/25
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5093 - tp: 43.0000 - fp: 104.0000 - tn: 82.0000 - fn: 6.0000 - accuracy: 0.5319 - precision: 0.2925 - recall: 0.8776 - auc: 0.7513 - prc: 0.4522 - val_loss: 0.7462 - val_tp: 10.0000 - val_fp: 24.0000 - val_tn: 22.0000 - val_fn: 2.0000 - val_accuracy: 0.5517 - val_precision: 0.2941 - val_recall: 0.8333 - val_auc: 0.7545 - val_prc: 0.4233
# Epoch 11/25
# 15/15 [==============================] - 0s 17ms/step - loss: 0.5115 - tp: 43.0000 - fp: 90.0000 - tn: 96.0000 - fn: 6.0000 - accuracy: 0.5915 - precision: 0.3233 - recall: 0.8776 - auc: 0.7482 - prc: 0.4526 - val_loss: 0.7687 - val_tp: 10.0000 - val_fp: 25.0000 - val_tn: 21.0000 - val_fn: 2.0000 - val_accuracy: 0.5345 - val_precision: 0.2857 - val_recall: 0.8333 - val_auc: 0.7582 - val_prc: 0.4274
# Epoch 12/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4964 - tp: 46.0000 - fp: 114.0000 - tn: 72.0000 - fn: 3.0000 - accuracy: 0.5021 - precision: 0.2875 - recall: 0.9388 - auc: 0.7623 - prc: 0.4988 - val_loss: 0.8621 - val_tp: 10.0000 - val_fp: 28.0000 - val_tn: 18.0000 - val_fn: 2.0000 - val_accuracy: 0.4828 - val_precision: 0.2632 - val_recall: 0.8333 - val_auc: 0.7618 - val_prc: 0.4280
# Epoch 13/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4877 - tp: 45.0000 - fp: 105.0000 - tn: 81.0000 - fn: 4.0000 - accuracy: 0.5362 - precision: 0.3000 - recall: 0.9184 - auc: 0.7642 - prc: 0.5175 - val_loss: 0.7042 - val_tp: 10.0000 - val_fp: 22.0000 - val_tn: 24.0000 - val_fn: 2.0000 - val_accuracy: 0.5862 - val_precision: 0.3125 - val_recall: 0.8333 - val_auc: 0.7763 - val_prc: 0.4619
# Epoch 14/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4915 - tp: 41.0000 - fp: 90.0000 - tn: 96.0000 - fn: 8.0000 - accuracy: 0.5830 - precision: 0.3130 - recall: 0.8367 - auc: 0.7672 - prc: 0.4620 - val_loss: 0.7301 - val_tp: 10.0000 - val_fp: 23.0000 - val_tn: 23.0000 - val_fn: 2.0000 - val_accuracy: 0.5690 - val_precision: 0.3030 - val_recall: 0.8333 - val_auc: 0.7654 - val_prc: 0.4351
# Epoch 15/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4886 - tp: 45.0000 - fp: 109.0000 - tn: 77.0000 - fn: 4.0000 - accuracy: 0.5191 - precision: 0.2922 - recall: 0.9184 - auc: 0.7800 - prc: 0.4582 - val_loss: 0.7920 - val_tp: 10.0000 - val_fp: 25.0000 - val_tn: 21.0000 - val_fn: 2.0000 - val_accuracy: 0.5345 - val_precision: 0.2857 - val_recall: 0.8333 - val_auc: 0.7663 - val_prc: 0.4384
# Epoch 16/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4849 - tp: 44.0000 - fp: 92.0000 - tn: 94.0000 - fn: 5.0000 - accuracy: 0.5872 - precision: 0.3235 - recall: 0.8980 - auc: 0.7778 - prc: 0.4931 - val_loss: 0.7248 - val_tp: 10.0000 - val_fp: 22.0000 - val_tn: 24.0000 - val_fn: 2.0000 - val_accuracy: 0.5862 - val_precision: 0.3125 - val_recall: 0.8333 - val_auc: 0.7627 - val_prc: 0.4329
# Epoch 17/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5122 - tp: 44.0000 - fp: 96.0000 - tn: 90.0000 - fn: 5.0000 - accuracy: 0.5702 - precision: 0.3143 - recall: 0.8980 - auc: 0.7364 - prc: 0.4481 - val_loss: 0.8317 - val_tp: 10.0000 - val_fp: 27.0000 - val_tn: 19.0000 - val_fn: 2.0000 - val_accuracy: 0.5000 - val_precision: 0.2703 - val_recall: 0.8333 - val_auc: 0.7563 - val_prc: 0.4321
# Epoch 18/25
# 12/15 [=======================>......] - ETA: 0s - loss: 0.4771 - tp: 38.0000 - fp: 80.0000 - tn: 70.0000 - fn: 4.0000 - accuracy: 0.5625 - precision: 0.3220 - recall: 0.9048 - auc: 0.8063 - prc: 0.5994 Restoring model weights from the end of the best epoch: 13.
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4768 - tp: 43.0000 - fp: 97.0000 - tn: 89.0000 - fn: 6.0000 - accuracy: 0.5617 - precision: 0.3071 - recall: 0.8776 - auc: 0.7958 - prc: 0.5471 - val_loss: 0.7164 - val_tp: 10.0000 - val_fp: 21.0000 - val_tn: 25.0000 - val_fn: 2.0000 - val_accuracy: 0.6034 - val_precision: 0.3226 - val_recall: 0.8333 - val_auc: 0.7636 - val_prc: 0.4427
# Epoch 18: early stopping
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch 1/25
# 15/15 [==============================] - 5s 100ms/step - loss: 0.6404 - tp: 43.0000 - fp: 185.0000 - tn: 47.0000 - fn: 18.0000 - accuracy: 0.3072 - precision: 0.1886 - recall: 0.7049 - auc: 0.5250 - prc: 0.2514 - val_loss: 0.9447 - val_tp: 12.0000 - val_fp: 46.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.2069 - val_precision: 0.2069 - val_recall: 1.0000 - val_auc: 0.7400 - val_prc: 0.3150
# Epoch 2/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5746 - tp: 49.0000 - fp: 177.0000 - tn: 9.0000 - fn: 0.0000e+00 - accuracy: 0.2468 - precision: 0.2168 - recall: 1.0000 - auc: 0.6511 - prc: 0.2904 - val_loss: 0.7932 - val_tp: 12.0000 - val_fp: 41.0000 - val_tn: 5.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.2931 - val_precision: 0.2264 - val_recall: 1.0000 - val_auc: 0.8116 - val_prc: 0.5943
# Epoch 3/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5625 - tp: 46.0000 - fp: 151.0000 - tn: 35.0000 - fn: 3.0000 - accuracy: 0.3447 - precision: 0.2335 - recall: 0.9388 - auc: 0.6822 - prc: 0.3223 - val_loss: 0.7523 - val_tp: 12.0000 - val_fp: 32.0000 - val_tn: 14.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.4483 - val_precision: 0.2727 - val_recall: 1.0000 - val_auc: 0.8034 - val_prc: 0.5916
# Epoch 4/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5406 - tp: 43.0000 - fp: 123.0000 - tn: 63.0000 - fn: 6.0000 - accuracy: 0.4511 - precision: 0.2590 - recall: 0.8776 - auc: 0.7324 - prc: 0.3914 - val_loss: 0.7183 - val_tp: 11.0000 - val_fp: 26.0000 - val_tn: 20.0000 - val_fn: 1.0000 - val_accuracy: 0.5345 - val_precision: 0.2973 - val_recall: 0.9167 - val_auc: 0.7953 - val_prc: 0.5864
# Epoch 5/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5183 - tp: 43.0000 - fp: 119.0000 - tn: 67.0000 - fn: 6.0000 - accuracy: 0.4681 - precision: 0.2654 - recall: 0.8776 - auc: 0.7531 - prc: 0.4905 - val_loss: 0.7061 - val_tp: 11.0000 - val_fp: 24.0000 - val_tn: 22.0000 - val_fn: 1.0000 - val_accuracy: 0.5690 - val_precision: 0.3143 - val_recall: 0.9167 - val_auc: 0.7989 - val_prc: 0.5903
# Epoch 6/25
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5369 - tp: 43.0000 - fp: 100.0000 - tn: 86.0000 - fn: 6.0000 - accuracy: 0.5489 - precision: 0.3007 - recall: 0.8776 - auc: 0.7053 - prc: 0.3654 - val_loss: 0.7670 - val_tp: 11.0000 - val_fp: 25.0000 - val_tn: 21.0000 - val_fn: 1.0000 - val_accuracy: 0.5517 - val_precision: 0.3056 - val_recall: 0.9167 - val_auc: 0.7980 - val_prc: 0.5911
# Epoch 7/25
# 12/15 [=======================>......] - ETA: 0s - loss: 0.5110 - tp: 32.0000 - fp: 87.0000 - tn: 68.0000 - fn: 5.0000 - accuracy: 0.5208 - precision: 0.2689 - recall: 0.8649 - auc: 0.7476 - prc: 0.4415Restoring model weights from the end of the best epoch: 2.
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5227 - tp: 42.0000 - fp: 102.0000 - tn: 84.0000 - fn: 7.0000 - accuracy: 0.5362 - precision: 0.2917 - recall: 0.8571 - auc: 0.7393 - prc: 0.4397 - val_loss: 0.6896 - val_tp: 11.0000 - val_fp: 21.0000 - val_tn: 25.0000 - val_fn: 1.0000 - val_accuracy: 0.6207 - val_precision: 0.3438 - val_recall: 0.9167 - val_auc: 0.7853 - val_prc: 0.5847
# Epoch 7: early stopping
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step

# %% [markdown]
# Compute mean AUC and PRC curves

# %%
# Determine the common set of FPR values
fpr_common_no_dupes = np.unique(np.concatenate(fprs))

# Interpolate the TPR values at the common set of FPR values for each fold
tprs_interp = []
for i in range(n_splits):
    tprs_interp.append(np.interp(fpr_common_no_dupes, fprs[i], tprs[i]))

# Calculate the mean and standard deviation of the interpolated TPR values and AUCs across all folds
mean_tpr_no_dupes = np.mean(tprs_interp, axis=0)
std_tpr_no_dupes = np.std(tprs_interp, axis=0)

# %%
# Determine the common set of recall values
recall_common_no_dupes = np.unique(np.concatenate(recalls))
# Interpolate the precision values at the common set of recall values for each fold
precisions_interp = []
for i in range(n_splits):
    precisions_interp.append(np.interp(recall_common_no_dupes, recalls[i][::-1], precisions[i][::-1]))
    
# Calculate the mean and standard deviation of the interpolated precision values and AUCs across all folds
mean_precision_no_dupes = np.mean(precisions_interp, axis=0)

# %% [markdown]
# ## Evaluation

# %%
# Calculate the AUC value
auc_value_dupes = auc(fpr_common_dupes, mean_tpr_dupes)
auc_value_3 = auc(roc_curve_onco['fpr_points'], roc_curve_onco['mean_tpr'])
auc_value_4 = auc(roc_curve_orig['fpr_points'], roc_curve_orig['mean_tpr'])
auc_value_no_dupes = auc(fpr_common_no_dupes, mean_tpr_no_dupes)

# Plot the ROC curve
plt.plot(fpr_common_no_dupes, mean_tpr_no_dupes, color='orange', label='Fine tuned MLP no duplicates (AUC = %0.2f)' % auc_value_no_dupes)

plt.plot(fpr_common_dupes, mean_tpr_dupes, color='red', label='Fine tuned MLP with duplicates (AUC = %0.2f)' % auc_value_dupes)

plt.plot(roc_curve_onco['fpr_points'], roc_curve_onco['mean_tpr'], color='green', label='Oncothromb no duplicates (AUC = %0.2f)' % auc_value_3)

plt.plot(roc_curve_orig['fpr_points'], roc_curve_orig['mean_tpr'], color='black', label='Oncothromb with duplicates (AUC = %0.2f)' % auc_value_4)

plt.plot([0, 1], [0, 1], 'k--', label='Random guess')

plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC Curve')
plt.legend(loc='best')

#plt.savefig('ROC_curve_MLP_fine_tuned_final.png', dpi=300)

plt.show()

# %%
# Plot the mean PR curve with shaded areas representing the standard deviation
plt.plot(recall_common_no_dupes, mean_precision_no_dupes, color='orange', label='Fine tuned MLP no duplicates (AP= ' + str(round(np.mean(aps_no_dupes),2)) + ')')

plt.plot(recall_common_dupes, mean_precision_dupes, color='red', label='Fine tuned MLP with duplicates (AP= ' + str(round(np.mean(aps),2)) + ')')


# Plot the real data Precision-Recall curve
ap = auc(pr_curve_onco.recall_points, pr_curve_onco.mean_precision)
ap_4 = auc(prc_curve_orig.recall, prc_curve_orig.precision)

plt.plot(pr_curve_onco.recall_points,pr_curve_onco.mean_precision, color='green', label='Oncothromb no duplicates (AP = %0.2f)' % ap)

plt.plot(prc_curve_orig.recall,prc_curve_orig.precision, color='black', label='Oncothromb with duplicates (AP = %0.2f)' % ap_4)

plt.plot()
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('PR Curve')
plt.legend()

#plt.savefig('PRC_curve_MLP_fine_tuned_final.png', dpi=300)
plt.show()
